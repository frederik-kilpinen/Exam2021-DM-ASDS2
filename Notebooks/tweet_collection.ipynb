# %% [markdown]
# # Data Collection

# %%
#Necessary imports
import pandas as pd
import numpy as np
from tqdm import tqdm
import tweepy
from datetime import date
import pickle 
import time
import json

# %%
#Get twitter credentials from AppCred.py.
#You must have your own credentials stored in working dir
from AppCred import API_KEY, API_SECRET
from AppCred import ACCESS_TOKEN, ACCESS_TOKEN_SECRET

# %% [markdown]
# ## Load MP data

# %%
#Filter by Australian Parlamentarians
#Download the file full_member_info at http://twitterpoliticians.org/download
mp_df = pd.read_csv("full_member_info.csv")
mp_df = mp_df[['p.country', 'm.name', 'p.party', 'm.uid']].copy()
mp_df = mp_df.loc[mp_df["p.country"]=="Australia"]
filtered_df =  mp_df.loc[mp_df["m.uid"] != "\\N"]

# %% [markdown]
# ## Get twitter handles

# %%
#Get the twitter handle of each politicians
#and add it to the df
def get_handle(uid):
    try:
        handle = api.get_user(uid).screen_name
    except:
        handle = np.nan
    return handle
            
filtered_df["twitter_handle"] = filtered_df["m.uid"].apply(lambda x: get_handle(x))

# %%
filtered_df.to_csv("australian_mps") #Create csv

# %% [markdown]
# ## Get Tweets

# %% [markdown]
# Having downloaded the csv with australians mps you can start from here.

# %%
filtered_df = pd.read_csv("data/australian_mps.csv")
#Get a list of unique twitter handles
handles = filtered_df["twitter_handle"].unique().tolist()

# %%
#Remove private and "nan"
handles.remove("JohnAlexanderMP")
handles.remove(np.nan)

# %%
class TweetCollector:
    
    def __init__(self):
        self.api = self.connect_api()
    

    def connect_api(self):
        """
        Connect to the API upon initalizing that class. You need to have
        your own credentials imported
        """
        auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
        auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
        api = tweepy.API(auth, wait_on_rate_limit= True, 
                         wait_on_rate_limit_notify=True, 
                         retry_count = 10, retry_delay = 5, 
                         retry_errors= set([401, 404, 500, 503]))
        
        return api
        
    def get_tweets(self, screen_name):
        """
        Given a screen name this method tries to fetch the last 3200 tweets (maximum allowed).
        """
        #initialize a list to hold all the tweepy Tweets
        all_tweets = []  
    
        #make initial request for most recent tweets
        new_tweets = self.api.user_timeline(screen_name = screen_name,
                                            count=200, tweet_mode = "extended")
    
        #save most recent tweets
        all_tweets.extend(new_tweets)
    
        #save the id of the oldest tweet less one
        oldest = all_tweets[-1].id - 1
            
            
        #keep grabbing tweets until there are no tweets left to grab
        while len(new_tweets) > 0:
            try:
                #all subsiquent requests use the max_id param to prevent duplicates
                new_tweets = self.api.user_timeline(screen_name = screen_name,count=200,
                                                    max_id=oldest, tweet_mode = "extended")

                #save most recent tweets
                all_tweets.extend(new_tweets)

                #update the id of the oldest tweet less one
                oldest = all_tweets[-1].id - 1
                    
            except tweepy.TweepError as e:
                print(e.reason)
                time.sleep(60)
                continue
                
            
        return all_tweets
    
    
    def pickle_dump(self, screen_names, dump = True):
        """
        Given a list of screen names, this method returns a dictionary
        containing all the fetchable tweets from the list of users.
        Dumps everything as a pickle file locally
        """
        
        if not isinstance(screen_names, list):
            screen_names = [screen_names]
        
        all_tweets = {}
        
        for screen_name in tqdm(screen_names):
            try:
                tweets = self.get_tweets(screen_name)
                all_tweets[screen_name] = tweets
            except:
                print(f"could not get {screen_name}")
                continue
         
        #If True dumps all the tweets in a pickle file
        if dump:
            with open(f'pickled_tweets_{str(date.today())}.data', 'wb') as f:
                # store the data as binary data stream
                pickle.dump(all_tweets, f)
                
        return all_tweets

# %%
#Initiate collector object
collector = TweetCollector()
#Dump tweets from 3 MPs
tweets = collector.pickle_dump(handles[0])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Failed to send request: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
# 100%|██████████| 1/1 [01:35<00:00, 95.33s/it]

# %%
tweets["AlanTudgeMP"][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-1c0ced211e80> in <module>
# ----> 1 dict(tweets["AlanTudgeMP"][0])
#
# TypeError: 'Status' object is not iterable

# %%
tweets["AlanTudgeMP"][0]._json
# Out:
# {'created_at': 'Mon Jun 07 11:03:25 +0000 2021',
#  'id': 1401857321416814599,
#  'id_str': '1401857321416814599',
#  'full_text': 'RT @RurbsOz: “If we seek to learn from Singapore’s world-leading practices in the teaching of mathematics, then we also need to adopt the S…',
#  'truncated': False,
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'RurbsOz',
#     'name': 'Rebecca Urban',
#     'id': 702210398,
#     'id_str': '702210398',
#     'indices': [3, 11]}],
#   'urls': []},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 185932331,
#   'id_str': '185932331',
#   'name': 'Alan Tudge',
#   'screen_name': 'AlanTudgeMP',
#   'location': 'Authorised by A Tudge, Liberal Party, Wantirna South, Victoria',
#   'description': 'Federal Member for Aston, Minister for Education and Youth',
#   'url': 'https://t.co/QSlbuhwDsP',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/QSlbuhwDsP',
#       'expanded_url': 'http://www.alantudge.com.au',
#       'display_url': 'alantudge.com.au',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 21948,
#   'friends_count': 441,
#   'listed_count': 333,
#   'created_at': 'Thu Sep 02 04:56:34 +0000 2010',
#   'favourites_count': 371,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 2936,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1140445027937574912/Y6fIAE0x_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1140445027937574912/Y6fIAE0x_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/185932331/1571808119',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sun Jun 06 22:56:29 +0000 2021',
#   'id': 1401674381965905920,
#   'id_str': '1401674381965905920',
#   'full_text': '“If we seek to learn from Singapore’s world-leading practices in the teaching of mathematics, then we also need to adopt the Singaporean adage of “I shall become creative once I have become a master.” Good op-ed in today’s SMH.\n https://t.co/F9wxpUIRiS',
#   'truncated': False,
#   'display_text_range': [0, 252],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/F9wxpUIRiS',
#      'expanded_url': 'https://www.smh.com.au/education/to-improve-australian-schools-cut-and-paste-won-t-cut-it-20210531-p57wnx.html',
#      'display_url': 'smh.com.au/education/to-i…',
#      'indices': [229, 252]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 702210398,
#    'id_str': '702210398',
#    'name': 'Rebecca Urban',
#    'screen_name': 'RurbsOz',
#    'location': 'Melbourne, Victoria',
#    'description': 'National education correspondent for The Australian. Good yarns "evangelist". DMs open. urbanr@theaustralian.com.au',
#    'url': 'https://t.co/otPWD6c1h0',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/otPWD6c1h0',
#        'expanded_url': 'http://www.theaustralian.com.au',
#        'display_url': 'theaustralian.com.au',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2360,
#    'friends_count': 1396,
#    'listed_count': 36,
#    'created_at': 'Wed Jul 18 02:39:16 +0000 2012',
#    'favourites_count': 4781,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 7414,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1334674953623334913/ZendiSIT_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334674953623334913/ZendiSIT_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/702210398/1607046338',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 33,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 9,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
tweets["AlanTudgeMP"][2].created_at
# Out:
# datetime.datetime(2021, 6, 7, 3, 10, 37)

# %%
class BuildTweetDF:
    """
    This class builds a Pandas dataframe using a pickle dump 
    of Tweepy tweet objects as collected by the TweetCollector
    """
    
    def __init__(self, pickle_dump):
        self.all_tweets = self.pickle_open(pickle_dump)
    
    def pickle_open(self, pickle_dump):
        with open(pickle_dump, 'rb') as f:
        # read the data as binary data stream
            all_tweets = pickle.load(f)
        
        return all_tweets
    
    def get_df(self):
        
        final_df_lst = []
        
        for politician, tweets in self.all_tweets.items():
            
            #Empty list for df. More things can be added later
            screen_name = []
            user_id = []
            created_at = []
            full_text = []
            favorite_count = []
            retweet_count = []
            tweet_id = []
            in_reply_to_screen_name = []
            hashtags = []
            user_mentions = []
            urls = []
            image = []
            
            for tweet in tweets:
                
                screen_name.append(tweet.user.screen_name)
                user_id.append(tweet.user.id)
                created_at.append(tweet.created_at)
                full_text.append(tweet.full_text)
                favorite_count.append(tweet.favorite_count)
                retweet_count.append(tweet.retweet_count)
                tweet_id.append(tweet.id)
                in_reply_to_screen_name.append(tweet.in_reply_to_screen_name)
                
                user_mentions.append([i["screen_name"] for i in tweet.entities["user_mentions"]])
                hashtags.append([i["text"] for i in tweet.entities["hashtags"]])
                
                try:
                    urls.append(tweet.entities["urls"][0]["expanded_url"])
                except:
                    urls.append(np.nan)    
                try:
                    image.append(tweet.entities["media"][0]["media_url"])
                except:
                    image.append(np.nan)
                            
                
            df = pd.DataFrame({"screen_name":screen_name,
                               "user_id":user_id,
                               "tweet_id":tweet_id,
                               "created_at":created_at,
                               "full_text":full_text,
                               "favorite_count":favorite_count,
                               "retweet_count":retweet_count,
                               "in_reply_to_screen_name":in_reply_to_screen_name,
                               "hashtags":hashtags,
                               "user_mentions":user_mentions,
                               "url":urls,
                               "image_url":image})
            
            #Append politican df to list of all dfs
            final_df_lst.append(df)
            
        #Concat to one final df
        final_df = pd.concat(final_df_lst).reset_index(drop=True)
        
        return final_df

# %%
#Load a pickle dump
build_df = BuildTweetDF("data/pickled_tweets_2021-05-04.data")

# %%
tweet_df = build_df.get_df()
#tweet_df.to_csv("mp_tweets")

# %%
tweet_df["image_url"][0][0]["media_url"]
# Out:
# 'http://pbs.twimg.com/media/E0hxzTAVgAQS3dT.jpg'

# %%
tweet_df.to_csv("mp_tweets")

# %%
#Subset bushfire tweets
bf_tweets = tweet_df.loc[(tweet_df["full_text"].str.contains("burnt|Koala|koala|fire|black summer|bushfire|Bushfire|Bush fire|bush fire|bush-fire|Bush-fire")) & 
             (tweet_df["created_at"] > "2019-06-01") & (tweet_df["created_at"] < "2020-04-01")].reset_index()

# %%
image_tweets = bf_tweets.loc[~bf_tweets["image_url"].isnull()].tail()
image_tweets.to_csv("image_tweets")

# %%
tweet_df.loc[(tweet_df["full_text"].str.contains("koala|Koala")) & 
            (tweet_df["created_at"] > "2019-06-01") & (tweet_df["created_at"] < "2020-04-01")]
# Out:
#             screen_name             tweet_id          created_at  \
# 6350     AndrewLamingMP  1197275047406080001 2019-11-20 22:06:30
# 6470     AndrewLamingMP  1181829729675923456 2019-10-09 07:12:19
# 27081        GregHuntMP  1216566236089221121 2020-01-13 03:42:48
# 36665    JoshFrydenberg  1216637740353110016 2020-01-13 08:26:55
# 36666    JoshFrydenberg  1216538757769252864 2020-01-13 01:53:36
# ...                 ...                  ...                 ...
# 311730  DarrenChesterMP  1217632570260643841 2020-01-16 02:20:01
# 324032   MakeMayoMatter  1221014815092568064 2020-01-25 10:19:51
# 324042   MakeMayoMatter  1216690441367605254 2020-01-13 11:56:20
# 324057   MakeMayoMatter  1213402604450934791 2020-01-04 10:11:39
# 327568        AdamBandt  1216598046265331713 2020-01-13 05:49:12
#
#                                                 full_text  favorite_count  \
# 6350    Supports Koala hospital. Rips off People Hospi...               0
# 6470    Peter Switzer reckons Councillors who oppose e...               0
# 27081   RT @JoshFrydenberg: Great to be at @HospitalKo...               0
# 36665   With around 8m hectares burnt, the #bushfires ...              57
# 36666   Great to be at @HospitalKoala in Port Macquari...             140
# ...                                                   ...             ...
# 311730  Not just helping humans... the crews on the gr...              80
# 324032  So sad to read Sam Mitchell has experienced a ...              23
# 324042  RT @wwf_uk: Wildlife rescuer Simon Adamczyk ca...               0
# 324057  RT @ElspethHussey7: People are being asked not...               0
# 327568  RT @sarahinthesen8: The government must act no...               0
#
#         retweet_count in_reply_to_screen_name  \
# 6350                0                    None
# 6470                1                    None
# 27081              58                    None
# 36665              17                    None
# 36666              58                    None
# ...               ...                     ...
# 311730             18                    None
# 324032              7                    None
# 324042            287                    None
# 324057            157                    None
# 327568            254                    None
#
#                                                  hashtags  \
# 6350                                                   []
# 6470                                                   []
# 27081                                                  []
# 36665                                         [bushfires]
# 36666                                         [bushfires]
# ...                                                   ...
# 311730  [YourADF, OpBushfireAssist, lovegippsland, TYFYS]
# 324032                           [istandwithSam, KIfires]
# 324042                                                 []
# 324057                                                 []
# 327568                                                 []
#
#                                             user_mentions  \
# 6350                                                   []
# 6470                                                   []
# 27081   [JoshFrydenberg, HospitalKoala, sussanley, Pat...
# 36665   [HospitalKoala, sussanley, PatConaghanMP, TSCo...
# 36666           [HospitalKoala, sussanley, PatConaghanMP]
# ...                                                   ...
# 311730                      [DeptDefence, AustralianArmy]
# 324032                                                 []
# 324042                                           [wwf_uk]
# 324057                                   [ElspethHussey7]
# 327568                                   [sarahinthesen8]
#
#                                                       url  image_url
# 6350    https://www.facebook.com/story.php?story_fbid=...        NaN
# 6470    https://www.theaustralian.com.au/business/prop...        NaN
# 27081                                                 NaN        NaN
# 36665                                                 NaN        NaN
# 36666                                                 NaN        NaN
# ...                                                   ...        ...
# 311730                                                NaN        NaN
# 324032         https://apple.news/ArrmGc_O4TriSjk1YP2xOnw        NaN
# 324042                                                NaN        NaN
# 324057                                                NaN        NaN
# 327568                                                NaN        NaN
#
# [81 rows x 11 columns]

# %%
sample = bf_tweets.sample(30).reset_index()

# %%
sample
# Out:
#     level_0   index      screen_name             tweet_id          created_at  \
# 0      1873  214423    MikeKellyofEM  1215833448964714496 2020-01-11 03:10:57
# 1       180   36707   JoshFrydenberg  1212849592963723264 2020-01-02 21:34:11
# 2        81   27075       GregHuntMP  1216878511077519360 2020-01-14 00:23:40
# 3        73   27064       GregHuntMP  1217947303496912900 2020-01-16 23:10:40
# 4      2738  318387    M_McCormackMP  1233266258864267264 2020-02-28 05:42:43
# 5       379   73069  ScottMorrisonMP  1193667545129050112 2019-11-10 23:11:34
# 6       840  102156       DaveSharma  1219210010665746433 2020-01-20 10:48:13
# 7      2023  223538  MThistlethwaite  1213712234989228033 2020-01-05 06:42:01
# 8      1982  214927    MikeKellyofEM  1197404942736084995 2019-11-21 06:42:39
# 9      1091  116646      AnneWerriwa  1213236864104067072 2020-01-03 23:13:03
# 10      241   60010  MichaelSukkarMP  1214091861440094208 2020-01-06 07:50:31
# 11     2645  311779  DarrenChesterMP  1214462568619630592 2020-01-07 08:23:34
# 12     1198  127969       BOConnorMP  1219495155029303301 2020-01-21 05:41:16
# 13      693   83105   stuartrobertmp  1213730113600122880 2020-01-05 07:53:03
# 14      934  106555           AlboMP  1215121416493785089 2020-01-09 04:01:36
# 15     1446  155111     JasonClareMP  1217327035950854145 2020-01-15 06:05:56
# 16      189   36940   JoshFrydenberg  1171745946687815681 2019-09-11 11:22:58
# 17     2604  311683  DarrenChesterMP  1220542294761205760 2020-01-24 03:02:14
# 18     2946  327784        AdamBandt  1202472678721875970 2019-12-05 06:20:02
# 19      924  106536           AlboMP  1215784083977986048 2020-01-10 23:54:48
# 20     1556  167653        Josh4Freo  1215588215844827137 2020-01-10 10:56:29
# 21     2047  232687    PeterKhalilMP  1236083175790505985 2020-03-07 00:16:09
# 22     1680  189533     lukejgosling  1216177728115769344 2020-01-12 01:59:00
# 23     1491  163890  JoanneRyanLalor  1234334544699908096 2020-03-02 04:27:42
# 24       33    6201   AndrewLamingMP  1220188784567828480 2020-01-23 03:37:30
# 25     3066  329739      Indigocathy  1213269362695524353 2020-01-04 01:22:12
# 26     2764  318476    M_McCormackMP  1217630380708098049 2020-01-16 02:11:19
# 27     2410  296244       gedkearney  1214792760651210752 2020-01-08 06:15:38
# 28     1549  167624        Josh4Freo  1217285597137522688 2020-01-15 03:21:17
# 29      673   83077   stuartrobertmp  1214676137147658240 2020-01-07 22:32:13
#
#                                             full_text  favorite_count  \
# 0   Bushfire states face $451m disaster funding cu...               6
# 1   Joining @LaTrioli this morning on @abcmelbourn...              12
# 2   RT @stuartrobertmp: SERVICE UPDATE: Services A...               0
# 3   RT @stuartrobertmp: The fastest and easiest wa...               0
# 4   It’s @ThankYouFireys Day. \n\nTerrific to meet...              11
# 5   I welcome the announcement a state of emergenc...             391
# 6   👉New initiatives to help support small busines...               3
# 7   Food and water loaded onto the second truck lo...              25
# 8   Bushfires burn earlier across Australia https:...               2
# 9   RT @AlboMP: This is something that we don’t ta...               0
# 10  RT @JoshFrydenberg: If you live in a bushfire ...               0
# 11  World famous Buchan Caves Reserve has suffered...             282
# 12  Media release: Holes in the Government’s small...              40
# 13  Update on Services Australia (Centrelink) #bus...               1
# 14  Access to medical care in bushfire-affected ar...             267
# 15  Federal and State MPs visit fire ravaged Highl...              10
# 16  RT @ScottMorrisonMP: My thoughts are with thos...               0
# 17  Kangaroo Island Wildlife Park in Pandana has b...             212
# 18  RT @bencubby: Seven fires across NSW are now b...               0
# 19  Media Conference on #bushfires and Parliament ...             295
# 20  Bushfire Watch and Act - in Spearwood, Beeliar...               2
# 21  Scientists confirm human-caused #climatechange...              23
# 22  Unfortunately it is one of the questions that ...              17
# 23  RT @BOConnorMP: Labor calls for more aid for s...               0
# 24  From Kangaroo Island: The fallout of the bushf...               1
# 25  RT @hula_grl: Great initiative by these women ...               0
# 26  RT @NSWRFS: Relief is here for a number of fir...               0
# 27  RT @AlboMP: Back in 2008, we were told we woul...               0
# 28  RT @MurrayWatt: 7 years in office and this gov...               0
# 29  SERVICES UPDATE: Services Australia (@Centreli...               2
#
#     retweet_count in_reply_to_screen_name                        hashtags  \
# 0              10                    None                              []
# 1               2                    None                              []
# 2               6                    None            [bushfires, YourADF]
# 3               2                    None                      [bushfire]
# 4               3                    None                              []
# 5             118                    None                              []
# 6               0                    None                              []
# 7               7                    None                              []
# 8               3                    None                              []
# 9            1175                    None                              []
# 10             23                    None                              []
# 11             66                    None                 [lovegippsland]
# 12             49                    None                        [auspol]
# 13              4                    None                     [bushfires]
# 14             65                  AlboMP                              []
# 15              3                    None                              []
# 16             71                    None                              []
# 17             70                    None              [OpBushfireAssist]
# 18             56                    None                              []
# 19             60                    None                     [bushfires]
# 20              1                    None                              []
# 21             14                    None  [climatechange, globalwarming]
# 22             12                    None                        [auspol]
# 23             42                    None                              []
# 24              1                    None                              []
# 25             10                    None                              []
# 26           1131                    None                              []
# 27           1166                    None                              []
# 28            158                    None                              []
# 29              4                    None                     [bushfires]
#
#                user_mentions  \
# 0                         []
# 1   [LaTrioli, abcmelbourne]
# 2           [stuartrobertmp]
# 3           [stuartrobertmp]
# 4           [ThankYouFireys]
# 5                         []
# 6                         []
# 7                         []
# 8            [canberratimes]
# 9                   [AlboMP]
# 10          [JoshFrydenberg]
# 11                        []
# 12                        []
# 13                        []
# 14                        []
# 15                        []
# 16         [ScottMorrisonMP]
# 17             [DeptDefence]
# 18                [bencubby]
# 19                        []
# 20                        []
# 21                  [wxrisk]
# 22                        []
# 23         [BOConnorMP, smh]
# 24                        []
# 25                [hula_grl]
# 26                  [NSWRFS]
# 27                  [AlboMP]
# 28              [MurrayWatt]
# 29              [Centrelink]
#
#                                                   url  image_url
# 0   https://www.afr.com/politics/federal/bushfire-...        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5   https://twitter.com/NSWRFS/status/119365419107...        NaN
# 6   https://www.pm.gov.au/media/immediate-small-bu...        NaN
# 7                                                 NaN        NaN
# 8   https://www.canberratimes.com.au/story/6504694...        NaN
# 9                                                 NaN        NaN
# 10                                                NaN        NaN
# 11                                                NaN        NaN
# 12                                                NaN        NaN
# 13  https://twitter.com/stuartrobertmp/status/1213...        NaN
# 14                                                NaN        NaN
# 15  https://www.southernhighlandnews.com.au/story/...        NaN
# 16                                                NaN        NaN
# 17                                                NaN        NaN
# 18                                                NaN        NaN
# 19                                                NaN        NaN
# 20  https://www.emergency.wa.gov.au/data/message_d...        NaN
# 21  https://www.nytimes.com/2020/03/04/climate/aus...        NaN
# 22  https://twitter.com/LeftyLongtitude/status/121...        NaN
# 23  https://www.smh.com.au/politics/federal/labor-...        NaN
# 24  https://www.facebook.com/story.php?story_fbid=...        NaN
# 25                                                NaN        NaN
# 26                                                NaN        NaN
# 27                                                NaN        NaN
# 28                                                NaN        NaN
# 29                                                NaN        NaN

# %%
sample["full_text"][28]
# Out:
# 'RT @MurrayWatt: 7 years in office and this government thinks it’s time for a bushfire/climate change roundtable.'
