# %% [markdown]
# # **LDA and hSBM topic models**

# %% [markdown]
# ## **Modules**

# %%
#Graph tool package
from sbmtm import sbmtm
import graph_tool.all as gt

#Necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm import tqdm

from datetime import datetime 
import logging 
import sys 
import pickle 
import requests
import io
import nltk
from nltk.tokenize import TweetTokenizer
import string
import re
from collections import defaultdict

# remove infrequent words
from collections import Counter

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')

#Importing packages for data visualization 
import matplotlib.pyplot as plt
import seaborn as sns

#Importing packages for LDA
from gensim.corpora.dictionary import Dictionary
from gensim.models.ldamulticore import LdaMulticore

# %% [markdown]
# ## **Preprocessing**

# %%
#Read the twitter data
path = "data/final_df.csv"
df = pd.read_csv(path, index_col = 0)

#Subset bushfire period
df = df.loc[(df["created_at"] >= "2019-06-01") & (df["created_at"] <= "2020-06-01")] #?

# Stringing stemmed tweets
df["stems"] = df["stems"].astype(str)

#Aggregate data on mp and day
df_agg = df.groupby(['name','created_at']).agg({"stems":" ".join, "party" : "first", "created_at":"first"}).reset_index(drop = True)

# %%
#--------------------------------
#Prepare tweets for topic model - are we removing most common word here? If so
#--------------------------------
def create_dfm(df):
    docs = df['stems'].str.split()
    titles = df["party"]

    cutoff = 5
    c = Counter()
    for doc in docs:
        c.update(Counter(doc))
    vocab = c.most_common(10000)
    vocab = set([w for w,count in vocab if count>5])

    # remove words
    docs = [[w for w in doc if w in vocab] for doc in docs]
    
    return docs, vocab


    # For LDA prep we remove words like this:
#id2word = Dictionary(df['stems']) 

#Removing very frequent and infrequent words
#id2word.filter_extremes(no_below=10, no_above=.999, keep_n = None)

# %% [markdown]
# ## **hSBM**

# %%
docs, vocab = create_dfm(df_agg)

# %%
#Note to self: docs is a list of docs, each containing list of words
## we create an instance of the sbmtm-class
model = sbmtm()

## we have to create the word-document network from the corpus
model.make_graph(docs)

## fit the model
gt.seed_rng(32) ## seed for graph-tool's random number generator --> same results
model.fit()

# %%
###----------------------------##
### Load trained model####
###----------------------------##

model.save_graph(filename = 'lemmas_graph.xml.gz')
#model = sbmtm()
#model.load_graph(filename = 'poslemmas_graph.xml.gz')
#gt.seed_rng(32) ## seed for graph-tool's random number generator --> same results
#model.fit()

# %%
#Plot the graph
model.plot(nedges=1000)

# %%
model.topics(l = 1, n = 25)
# Out:
# {0: [('climate', 0.07859848484848485),
#   ('liberal', 0.07523674242424243),
#   ('via', 0.03868371212121212),
#   ('daily', 0.025236742424242425),
#   ('vote', 0.023816287878787878),
#   ('bill', 0.023674242424242424),
#   ('coal', 0.01950757575757576),
#   ('senate', 0.01950757575757576),
#   ('law', 0.018513257575757575),
#   ('canberratimes', 0.017992424242424244),
#   ('promise', 0.013778409090909091),
#   ('debt', 0.013020833333333334),
#   ('debate', 0.011695075757575758),
#   ('integrity', 0.011410984848484849),
#   ('inquiry', 0.010511363636363636),
#   ('libs', 0.009848484848484848),
#   ('❤', 0.0078125),
#   ('newstart', 0.007528409090909091),
#   ('#canberra', 0.007433712121212121),
#   ('ipswich', 0.007054924242424243),
#   ('independent', 0.007007575757575758),
#   ('labour', 0.0069602272727272724),
#   ('podcast', 0.0069602272727272724),
#   ('weak', 0.006297348484848485),
#   ('oppose', 0.0060132575757575754)],
#  1: [('worker', 0.08631278267079266),
#   ('crisis', 0.05536776957867175),
#   ('billion', 0.029754820280885504),
#   ('security', 0.022899309688169483),
#   ('thousand', 0.018900261842418473),
#   ('art', 0.018281361580576052),
#   ('green', 0.01790049988098072),
#   ('gov', 0.01461556772197096),
#   ('treasurer', 0.014091882885027374),
#   ('unemployment', 0.013187336348488454),
#   ('nurse', 0.012187574387050702),
#   ('parent', 0.012139966674601285),
#   ('housing', 0.011949535824803618),
#   ('visa', 0.011901928112354201),
#   ('teacher', 0.011616281837657701),
#   ('vulnerable', 0.010854558438467032),
#   ('hundred', 0.010045227326826946),
#   ('figure', 0.009569150202332777),
#   ('push', 0.009569150202332777),
#   ('childcare', 0.008855034515591526),
#   ('university', 0.00804570340395144),
#   ('newswire', 0.007664841704356106),
#   ('homeland', 0.007617233991906689),
#   ('double', 0.007379195429659605),
#   ('charity', 0.0073315877172101885)],
#  2: [('labor', 0.0735312345066931),
#   ('–', 0.04564328210213188),
#   ('parliament', 0.0443728309370352),
#   ('care', 0.04211080813088745),
#   ('plan', 0.041831928606841845),
#   ('👇', 0.034209221616261776),
#   ('house', 0.022093455627169065),
#   ('ask', 0.022031482399603373),
#   ('👏', 0.019490580069410016),
#   ('question', 0.019428606841844324),
#   ('age', 0.019056767476450173),
#   ('stand', 0.018963807635101637),
#   ('power', 0.018591968269707486),
#   ('old', 0.0173834903321765),
#   ('try', 0.015958106098165593),
#   ('win', 0.015338373822508676),
#   ('energy', 0.015276400594942985),
#   ('🏼', 0.015059494298463065),
#   ('record', 0.01412989588497769),
#   ('hold', 0.01301437778879524),
#   ('education', 0.012394645513138325),
#   ('union', 0.012115765989092713),
#   ('address', 0.011527020327218642),
#   ('answer', 0.011372087258304412),
#   ('wait', 0.011341100644521566)],
#  3: [('time', 0.04269974782947179),
#   ('make', 0.04009342156481121),
#   ('say', 0.03899334879076616),
#   ('one', 0.03779173083757849),
#   ('u', 0.02985428266793034),
#   ('take', 0.02938040516526478),
#   ('many', 0.026232504611843552),
#   ('look', 0.01958129537800193),
#   ('want', 0.019479750198859308),
#   ('right', 0.018362753228290486),
#   ('would', 0.017008817506388885),
#   ('dont', 0.016974969113341343),
#   ('give', 0.016416470628056932),
#   ('im', 0.015891820535820063),
#   ('way', 0.01548563981924958),
#   ('think', 0.014064007311252898),
#   ('every', 0.014013234721681589),
#   ('much', 0.013759371773825038),
#   ('tell', 0.012066952121448035),
#   ('could', 0.011508453636163624),
#   ('even', 0.010949955150879213),
#   ('thats', 0.010916106757831672),
#   ('long', 0.010594547023880041),
#   ('hard', 0.00969756460812023),
#   ('wont', 0.008800582192360417)],
#  4: [('fire', 0.07125890736342043),
#   ('bushfire', 0.0473739773027184),
#   ('emergency', 0.04005014515703352),
#   ('bushfires', 0.03721298495645289),
#   ('volunteer', 0.03477170757455793),
#   ('grant', 0.03299023489047242),
#   ('club', 0.03081287938770124),
#   ('christmas', 0.02124571126946424),
#   ('review', 0.01728688308260755),
#   ('firefighter', 0.016363156505674322),
#   ('present', 0.014845605700712588),
#   ('season', 0.013525996305093692),
#   ('burn', 0.012074425969912905),
#   ('aust', 0.011546582211665346),
#   ('building', 0.011150699392979678),
#   ('station', 0.010688836104513063),
#   ('declare', 0.01035893375560834),
#   ('hill', 0.009765109527579837),
#   ('girl', 0.009633148588017946),
#   ('fuel', 0.009039324359989442),
#   ('reduction', 0.008907363420427554),
#   ('forum', 0.008841382950646608),
#   ('export', 0.008775402480865663),
#   ('scientist', 0.00844550013196094),
#   ('unprecedented', 0.00831353919239905)],
#  5: [('…', 0.21710260729150715),
#   ('people', 0.047371131867978894),
#   ('work', 0.04710664420841627),
#   ('get', 0.044698414466082935),
#   ('day', 0.03489845065913109),
#   ('good', 0.03460612219329872),
#   ('go', 0.02992886673998079),
#   ('see', 0.023316675250915266),
#   ('family', 0.02245361025655303),
#   ('well', 0.021186853571279425),
#   ('come', 0.0177763548032351),
#   ('like', 0.017386583515458607),
#   ('know', 0.017261299887244733),
#   ('life', 0.016119826830185),
#   ('last', 0.015980622798836254),
#   ('big', 0.014059607166223533),
#   ('country', 0.013307905396940295),
#   ('pay', 0.01238915879003856),
#   ('also', 0.01198546709912719),
#   ('still', 0.011526093795676323),
#   ('lose', 0.010955357267146457),
#   ('another', 0.010342859529211965),
#   ('let', 0.010315018722942217),
#   ('put', 0.010189735094728343),
#   ('leave', 0.009869565822626223)],
#  6: [('tax', 0.06955406471981057),
#   ('break', 0.04755327545382794),
#   ('taylor', 0.026736385161799527),
#   ('angus', 0.022691397000789267),
#   ('#qt', 0.022099447513812154),
#   ('violence', 0.01983030781373323),
#   ('skill', 0.017758484609313337),
#   ('rd', 0.01568666140489345),
#   ('❌', 0.014798737174427782),
#   ('tafe', 0.013812154696132596),
#   ('motion', 0.013812154696132596),
#   ('gap', 0.012726913970007893),
#   ('apprentice', 0.011345698500394633),
#   ('block', 0.010161799526440411),
#   ('investigation', 0.009865824782951855),
#   ('document', 0.009668508287292817),
#   ('pensioner', 0.009372533543804263),
#   ('n', 0.008287292817679558),
#   ('privatise', 0.008188634569850039),
#   ('privatisation', 0.007991318074191003),
#   ('mislead', 0.007991318074191003),
#   ('shortage', 0.00749802683504341),
#   ('tranche', 0.00749802683504341),
#   ('split', 0.007399368587213891),
#   ('transparency', 0.007300710339384372)],
#  7: [('service', 0.09941149319178398),
#   ('health', 0.09675744288022156),
#   ('economic', 0.05423494114931918),
#   ('please', 0.048003692591737826),
#   ('centre', 0.037214401107777524),
#   ('announce', 0.03709900761597046),
#   ('update', 0.03456035079621509),
#   ('advice', 0.028098315255019615),
#   ('b', 0.027579044541887837),
#   ('information', 0.026309716132010153),
#   ('mental', 0.022501730902377105),
#   ('medical', 0.0210016155088853),
#   ('available', 0.01713593353334872),
#   ('officer', 0.016558966074313407),
#   ('remain', 0.015289637664435725),
#   ('chief', 0.015231940918532194),
#   ('travel', 0.014712670205400416),
#   ('online', 0.013443341795522732),
#   ('measure', 0.013270251557812139),
#   ('detail', 0.013270251557812139),
#   ('phone', 0.013154858066005077),
#   ('march', 0.012347103623355643),
#   ('difficult', 0.01217401338564505),
#   ('👉', 0.01217401338564505),
#   ('info', 0.010558504500346181)],
#  8: [('job', 0.04497807146930989),
#   ('minister', 0.0392156862745098),
#   ('business', 0.03136861565087419),
#   ('govt', 0.027553247979231813),
#   ('million', 0.022439868625484295),
#   ('medium', 0.021849863315436504),
#   ('release', 0.01897850413987059),
#   ('regional', 0.014986134875213877),
#   ('nsw', 0.01478946643853128),
#   ('industry', 0.014081460066473931),
#   ('prime', 0.013452121069089622),
#   ('happy', 0.011957440950301886),
#   ('small', 0.011780439357287549),
#   ('ensure', 0.011603437764273212),
#   ('response', 0.011465769858595393),
#   ('impact', 0.011229767734576278),
#   ('nan', 0.00987275552146636),
#   ('sector', 0.009735087615788542),
#   ('place', 0.009676087084783763),
#   ('force', 0.009499085491769426),
#   ('area', 0.009420418117096388),
#   ('close', 0.00930241705508683),
#   ('international', 0.009086081774735973),
#   ('clear', 0.009007414400062934),
#   ('region', 0.008889413338053376)],
#  9: [('today', 0.08758284493618886),
#   ('year', 0.05639845903854229),
#   ('great', 0.05371455697358091),
#   ('national', 0.031385222106589256),
#   ('first', 0.02415511858465246),
#   ('‘', 0.020740903032626753),
#   ('state', 0.018769056617553084),
#   ('morning', 0.018422157711197533),
#   ('part', 0.014825363787405744),
#   ('talk', 0.01467930108999288),
#   ('next', 0.013766409231162477),
#   ('across', 0.013693377882456044),
#   ('th', 0.013236931953040843),
#   ('member', 0.012780486023625642),
#   ('high', 0.012579649814682953),
#   ('start', 0.012287524419857223),
#   ('around', 0.012269266582680616),
#   ('hear', 0.01205017253656132),
#   ('issue', 0.012013656862208103),
#   ('strong', 0.011922367676325063),
#   ('leader', 0.01175804714173559),
#   ('since', 0.011648500118675941),
#   ('proud', 0.011447663909733253),
#   ('program', 0.011319859049496997),
#   ('never', 0.01100947581749466)],
#  10: [('new', 0.05082459988626208),
#   ('community', 0.042781704443902835),
#   ('local', 0.02674465838004712),
#   ('thank', 0.02162645218945487),
#   ('school', 0.01723941831180437),
#   ('meet', 0.01475343244780242),
#   ('visit', 0.014314729060037371),
#   ('best', 0.012982370623121294),
#   ('fund', 0.012397432772767893),
#   ('open', 0.012023722479486555),
#   ('future', 0.011974977658623771),
#   ('deliver', 0.01161751563896336),
#   ('team', 0.011520025997237794),
#   ('project', 0.011146315703956454),
#   ('congratulation', 0.009911446908765944),
#   ('safe', 0.00986270208790316),
#   ('honour', 0.008871557397026567),
#   ('student', 0.008855309123405639),
#   ('discuss', 0.008741571208059143),
#   ('drought', 0.008400357462019661),
#   ('infrastructure', 0.008172881631326671),
#   ('wonderful', 0.008124136810463888),
#   ('create', 0.007977902347875538),
#   ('build', 0.007539198960110488),
#   ('opportunity', 0.007457957592005849)],
#  11: [('government', 0.08300010807305738),
#   ('australian', 0.0749255067854441),
#   ('need', 0.051272946225934445),
#   ('australia', 0.04974448441432122),
#   ('call', 0.02408485278905683),
#   ('week', 0.023652560559509657),
#   ('thanks', 0.02118231924781152),
#   ('back', 0.01883559000169829),
#   ('must', 0.017152738108103936),
#   ('federal', 0.016180080591622795),
#   ('show', 0.014944959935773727),
#   ('join', 0.014327399607849192),
#   ('world', 0.014111253493075605),
#   ('public', 0.013756156304518997),
#   ('️', 0.013740717296320884),
#   ('cant', 0.01293788887001899),
#   ('australias', 0.012721742755245404),
#   ('news', 0.012629108706056724),
#   ('speak', 0.011440305074801994),
#   ('child', 0.011440305074801994),
#   ('use', 0.011301354001018974),
#   ('month', 0.01091537879606614),
#   ('report', 0.010807305738679347),
#   ('live', 0.01077642772228312),
#   ('stop', 0.010760988714085007)],
#  12: [('woman', 0.04897691344031498),
#   ('emission', 0.03322794249239396),
#   ('target', 0.017717592316411145),
#   ('resource', 0.017598281930442047),
#   ('zero', 0.01539103979001372),
#   ('net', 0.013422418421523594),
#   ('sad', 0.011215176281095269),
#   ('car', 0.010737934737218876),
#   ('carbon', 0.010081727614388832),
#   ('photo', 0.00942552049155879),
#   ('treat', 0.009365865298574241),
#   ('citizen', 0.008351727017836902),
#   ('bob', 0.008351727017836902),
#   ('street', 0.007934140666945057),
#   ('flag', 0.00775517508799141),
#   ('aid', 0.00769551989500686),
#   ('blue', 0.007635864702022311),
#   ('ceremony', 0.007456899123068663),
#   ('commissioner', 0.0072779335441150155),
#   ('dutton', 0.006920002386207719),
#   ('dad', 0.006502416035315874),
#   ('guy', 0.006502416035315874),
#   ('body', 0.0062041400703931274),
#   ('ad', 0.00602517449143948),
#   ('option', 0.005965519298454931)],
#  13: [('science', 0.05542216886754702),
#   ('disability', 0.05542216886754702),
#   ('ndis', 0.04821928771508603),
#   ('#ndis', 0.04221688675470188),
#   ('tim', 0.03941576630652261),
#   ('participant', 0.02661064425770308),
#   ('tribute', 0.022609043617446978),
#   ('vale', 0.021608643457382955),
#   ('recipient', 0.020608243297318928),
#   ('quarter', 0.018207282913165267),
#   ('peace', 0.016606642657062826),
#   ('insurance', 0.016606642657062826),
#   ('fischer', 0.016606642657062826),
#   ('courage', 0.016206482593037214),
#   ('condolence', 0.015806322529011603),
#   ('prize', 0.014605842336934774),
#   ('carers', 0.013005202080832333),
#   ('tech', 0.012605042016806723),
#   ('giant', 0.012404961984793917),
#   ('passing', 0.012204881952781112),
#   ('#npc', 0.012004801920768308),
#   ('brown', 0.012004801920768308),
#   ('donor', 0.011604641856742696),
#   ('stem', 0.011204481792717087),
#   ('richard', 0.011004401760704281)],
#  14: [('support', 0.11856864403662977),
#   ('help', 0.08488102681034165),
#   ('-', 0.06590415946452871),
#   ('home', 0.050200433967121476),
#   ('keep', 0.04832481335736089),
#   ('important', 0.04523555588246111),
#   ('continue', 0.034276047221507115),
#   ('provide', 0.031370674120113275),
#   ('include', 0.028502077893420616),
#   ('together', 0.02666323415836122),
#   ('stay', 0.023684307307565003),
#   ('protect', 0.021845463572505608),
#   ('access', 0.020999595454378288),
#   ('save', 0.020631826707366407),
#   ('social', 0.019123974844617704),
#   ('weve', 0.018241329851789195),
#   ('step', 0.016659924239638114),
#   ('test', 0.01625537861792505),
#   ('follow', 0.0151888492515906),
#   ('message', 0.014857857379279908),
#   ('food', 0.010628516788643301),
#   ('current', 0.00978264867051598),
#   ('soon', 0.009378103048802914),
#   ('essential', 0.009341326174101725),
#   ('contact', 0.008826449928285095)],
#  15: [('indigenous', 0.037894923677671284),
#   ('🇺', 0.035942492012779555),
#   ('🇦', 0.03194888178913738),
#   ('budget', 0.026979055733049342),
#   ('cancer', 0.025381611643592473),
#   ('improve', 0.02511537096201633),
#   ('agreement', 0.01615193468228612),
#   ('patient', 0.01579694710685126),
#   ('suicide', 0.01579694710685126),
#   ('#forthebeaches', 0.012868299609513667),
#   ('loan', 0.012690805821796236),
#   ('medicine', 0.012335818246361378),
#   ('yr', 0.012247071352502662),
#   ('relationship', 0.011980830670926517),
#   ('awareness', 0.011359602413915513),
#   ('outcome', 0.011270855520056798),
#   ('congestion', 0.011004614838480652),
#   ('treatment', 0.010117145899893504),
#   ('sooner', 0.009939652112176074),
#   ('#followfalinski', 0.008874689385871494),
#   ('enter', 0.007987220447284345),
#   ('pb', 0.007987220447284345),
#   ('#mackellarvotes', 0.007632232871849485),
#   ('indonesia', 0.007454739084132056),
#   ('prevention', 0.007277245296414625)],
#  16: [('sport', 0.033359497645211934),
#   ('claim', 0.024201988487702775),
#   ('commission', 0.02230507587650445),
#   ('shadow', 0.01942700156985871),
#   ('refuse', 0.01870748299319728),
#   ('press', 0.016810570381998954),
#   ('royal', 0.016287284144427),
#   ('democracy', 0.01543694400837258),
#   ('robodebt', 0.0141287284144427),
#   ('rorts', 0.012362637362637362),
#   ('victim', 0.012231815803244374),
#   ('co', 0.01164311878597593),
#   ('freedom', 0.011512297226582941),
#   ('implement', 0.011185243328100471),
#   ('department', 0.010269492412349555),
#   ('scandal', 0.009942438513867086),
#   ('ignore', 0.009419152276295133),
#   ('mckenzie', 0.009157509157509158),
#   ('lnp', 0.008634222919937205),
#   ('deny', 0.008634222919937205),
#   ('justice', 0.008437990580847723),
#   ('journalist', 0.008176347462061747),
#   ('bridget', 0.007914704343275772),
#   ('hunt', 0.007522239665096808),
#   ('retail', 0.007456828885400314)],
#  17: [('#auspol', 0.15372374283895607),
#   ('morrison', 0.0911405589954285),
#   ('change', 0.044123603958104274),
#   ('scott', 0.037555697008274984),
#   ('economy', 0.0364851571089636),
#   ('pm', 0.03168219431745848),
#   ('cut', 0.028412707597939933),
#   ('policy', 0.024043747468317805),
#   ('action', 0.02389907991435681),
#   ('act', 0.018604247439384294),
#   ('mp', 0.017880909669579306),
#   ('party', 0.017765175626410508),
#   ('growth', 0.016289566576008333),
#   ('rate', 0.015595162316995544),
#   ('low', 0.015276893698281349),
#   ('#ausecon', 0.014669289971645159),
#   ('election', 0.01464035646085296),
#   ('interest', 0.013888085180255772),
#   ('speech', 0.013280481453619581),
#   ('campaign', 0.01275967825935999),
#   ('coalition', 0.012470343151437996),
#   ('point', 0.012470343151437996),
#   ('political', 0.010126728777269833),
#   ('fact', 0.009374457496672647),
#   ('rise', 0.008882587813205254)],
#  18: [('wage', 0.16452032990884097),
#   ('subsidy', 0.0792938793228187),
#   ('early', 0.0729272174793807),
#   ('✅', 0.03689769931992476),
#   ('amendment', 0.029662856316017942),
#   ('employer', 0.02619013167414267),
#   ('foreign', 0.024164375633048765),
#   ('register', 0.021704529011720444),
#   ('learning', 0.017363623209376358),
#   ('rent', 0.014324989147735494),
#   ('defeat', 0.014324989147735494),
#   ('eviction', 0.012443929966719723),
#   ('conflict', 0.012154536246563449),
#   ('educator', 0.01172044566632904),
#   ('childhood', 0.011286355086094631),
#   ('freeze', 0.010996961365938359),
#   ('hub', 0.010273477065547678),
#   ('mortgage', 0.009260599045000723),
#   ('hopefully', 0.008826508464766314),
#   ('tenant', 0.008537114744610042),
#   ('search', 0.008537114744610042),
#   ('disappointing', 0.008392417884531905),
#   ('anxious', 0.007668933584141224),
#   ('worried', 0.007379539863984951),
#   ('confusion', 0.007234843003906815)],
#  19: [('coronavirus', 0.0864153627311522),
#   ('covid', 0.053129445234708396),
#   ('#covid', 0.040682788051209104),
#   ('package', 0.040327169274537694),
#   ('payment', 0.03677098150782361),
#   ('jobkeeper', 0.032788051209103844),
#   ('#coronavirus', 0.030796586059743954),
#   ('pandemic', 0.023470839260312945),
#   ('spread', 0.021479374110953058),
#   ('stimulus', 0.018349928876244665),
#   ('centrelink', 0.015007112375533429),
#   ('casual', 0.013869132290184922),
#   ('casuals', 0.012731152204836416),
#   ('virus', 0.012588904694167851),
#   ('#covidaus', 0.01209103840682788),
#   ('racism', 0.011948790896159318),
#   ('temporary', 0.010881934566145092),
#   ('#covidau', 0.010739687055476529),
#   ('ship', 0.010526315789473684),
#   ('distancing', 0.010526315789473684),
#   ('restriction', 0.010170697012802276),
#   ('#jobkeeper', 0.00945945945945946),
#   ('virgin', 0.009388335704125178),
#   ('frontline', 0.009388335704125178),
#   ('overseas', 0.009174964438122333)],
#  20: [('#tyfys', 0.11592528403620259),
#   ('•', 0.06970922395532447),
#   ('#lovegippsland', 0.06605045253225496),
#   ('app', 0.05738494126709032),
#   ('download', 0.036587714230695165),
#   ('#ourveterans', 0.02984787213556711),
#   ('covidsafe', 0.027151935297515885),
#   ('#regionsmatter', 0.026959368380512227),
#   ('gippsland', 0.02503369921047564),
#   ('#live', 0.017908723281340265),
#   ('enlist', 0.015405353360292702),
#   ('#waggawagga', 0.014635085692278067),
#   ('arrangement', 0.014635085692278067),
#   ('#improud', 0.014635085692278067),
#   ('ease', 0.012901983439245137),
#   ('\xad', 0.012709416522241479),
#   ('#covidsafe', 0.01116888118621221),
#   ('entrance', 0.010591180435201233),
#   ('bega', 0.010398613518197574),
#   ('marlo', 0.009820912767186597),
#   ('wagga', 0.008858078182168303),
#   ('trace', 0.008858078182168303),
#   ('corporal', 0.008665511265164644),
#   ('casino', 0.008665511265164644),
#   ('guinea', 0.008665511265164644)],
#  21: [('road', 0.04198534098151689),
#   ('council', 0.03409815168897387),
#   ('water', 0.027644996813256852),
#   ('meeting', 0.02637029955385596),
#   ('queensland', 0.026051625239005737),
#   ('pacific', 0.02278521351179095),
#   ('market', 0.021191841937539833),
#   ('qld', 0.0207138304652645),
#   ('bank', 0.019837476099426387),
#   ('coast', 0.018562778840025496),
#   ('reform', 0.016411727214786488),
#   ('#', 0.014420012746972594),
#   ('upgrade', 0.013782664117272149),
#   ('g', 0.013145315487571701),
#   ('importance', 0.012746972594008922),
#   ('rail', 0.0124282982791587),
#   ('strategy', 0.011153601019757807),
#   ('gold', 0.010675589547482474),
#   ('beach', 0.01035691523263225),
#   ('digital', 0.010038240917782026),
#   ('bridge', 0.008444869343530911),
#   ('port', 0.008205863607393244),
#   ('airport', 0.008046526449968132),
#   ('truck', 0.0076481835564053535),
#   ('governor', 0.007568514977692798)],
#  22: [('recovery', 0.04064255617977528),
#   ('remember', 0.03967696629213483),
#   ('serve', 0.03871137640449438),
#   ('disaster', 0.031425561797752806),
#   ('veteran', 0.031425561797752806),
#   ('forget', 0.028089887640449437),
#   ('war', 0.026773174157303372),
#   ('east', 0.021067415730337078),
#   ('post', 0.020101825842696628),
#   ('#youradf', 0.017819522471910113),
#   ('air', 0.0175561797752809),
#   ('adf', 0.016327247191011238),
#   ('personnel', 0.015098314606741573),
#   ('#bushfires', 0.01483497191011236),
#   ('anzac', 0.012816011235955056),
#   ('lake', 0.012640449438202247),
#   ('battle', 0.012201544943820225),
#   ('l', 0.011060393258426966),
#   ('recover', 0.010182584269662922),
#   ('military', 0.010007022471910113),
#   ('sacrifice', 0.009129213483146067),
#   ('property', 0.009041432584269662),
#   ('affected', 0.008690308988764045),
#   ('army', 0.00860252808988764),
#   ('immediate', 0.008426966292134831)]}

# %%
model.print_topics(l = 1)

# %%
len(model.documents)

# %%
#This takes ages, about 6h for me...
doc_topic_dist = []
for doc_i in tqdm(range(len(model.documents))):
    topic_dist = model.topicdist(doc_i, l = 1)
    doc_topic_dist.append(topic_dist)
# Out:
#  19%|█▉        | 366/1935 [8:42:43<37:20:51, 85.69s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-79dfb9bcba27> in <module>
#       2 doc_topic_dist = []
#       3 for doc_i in tqdm(range(len(model.documents))):
# ----> 4     topic_dist = model.topicdist(doc_i, l = 1)
#       5     doc_topic_dist.append(topic_dist)
#
# ~/University/m1/semester-2/ASDK20006U Advanced Social Data Science II/ASDS2/Notebooks/sbmtm.py in topicdist(self, doc_index, l)
#     401     def topicdist(self, doc_index, l=0):
#     402         # dict_groups =  self.groups[l]
# --> 403         dict_groups = self.get_groups(l=l)
#     404
#     405         p_tw_d = dict_groups['p_tw_d']
#
# ~/University/m1/semester-2/ASDK20006U Advanced Social Data Science II/ASDS2/Notebooks/sbmtm.py in get_groups(self, l)
#     607             v2 = e.target()
#     608             if counts:
# --> 609                 weight = g.ep["count"][e]
#     610             else:
#     611                 weight = 1
#
# ~/miniconda3/envs/graph-tool/lib/python3.7/site-packages/graph_tool/__init__.py in __getitem__(self, k)
#     884         PropertyMap.__init__(self, pmap, g, "e")
#     885
# --> 886     def __getitem__(self, k):
#     887         return self._PropertyMap__map[k]
#     888
#
# KeyboardInterrupt:

# %%
df_agg["topic_dist"] = doc_topic_dist
df.to_csv("lemmas_topic_df.csv")

# %%
model.topics(l=1,n=20)
# Out:
# /home/matiasp/University/m1/semester-2/ASDK20006U Advanced Social Data Science II/ASDS2/Notebooks/sbmtm.py:634: RuntimeWarning: invalid value encountered in true_divide
#   p_td_d = (n_db/np.sum(n_db,axis=1)[:,np.newaxis]).T
# /home/matiasp/University/m1/semester-2/ASDK20006U Advanced Social Data Science II/ASDS2/Notebooks/sbmtm.py:640: RuntimeWarning: invalid value encountered in true_divide
#   p_tw_d = (n_dbw/np.sum(n_dbw,axis=1)[:,np.newaxis]).T
# {0: [('climat', 0.07793607648326928),
#   ('liber', 0.07582716280813571),
#   ('via', 0.03814790514574937),
#   ('👏', 0.0294779267035336),
#   ('daili', 0.024978910863248664),
#   ('#ausecon', 0.023760427406504827),
#   ('coal', 0.01930827631455619),
#   ('canberratim', 0.017808604367794544),
#   ('fail', 0.014949854719280158),
#   ('wa', 0.014949854719280158),
#   ('fair', 0.014434342487580841),
#   ('promis', 0.014200018745899335),
#   ('debt', 0.012887805792482894),
#   ('lib', 0.01209110507076577),
#   ('perth', 0.011856781329084264),
#   ('🏻', 0.01110694535570344),
#   ('congrat', 0.01110694535570344),
#   ('frydenberg', 0.009747867653950698),
#   ('josh', 0.008623113693879464),
#   ('failur', 0.008341925203861655)],
#  1: [('govern', 0.0667485114480388),
#   ('peopl', 0.04192498925787244),
#   ('need', 0.04090602172978945),
#   ('get', 0.032791111656742984),
#   ('time', 0.03150205635013197),
#   ('make', 0.021140507028420602),
#   ('go', 0.02083358909827512),
#   ('call', 0.01936038303357682),
#   ('mani', 0.019004358234608065),
#   ('–', 0.01808360444417163),
#   ('like', 0.01642624762138604),
#   ('want', 0.014130501503897858),
#   ('pm', 0.01382358357375238),
#   ('crisi', 0.013700816401694188),
#   ('must', 0.013639432815665091),
#   ('right', 0.013344791602725432),
#   ('know', 0.013099257258609049),
#   ('dont', 0.012313547357436621),
#   ('also', 0.010557976797004482),
#   ('cant', 0.01027561230127064)],
#  2: [('#auspol', 0.09961010722051436),
#   ('morrison', 0.059027517432706005),
#   ('labor', 0.04451900727299993),
#   ('chang', 0.028829571867736374),
#   ('plan', 0.02613031416360501),
#   ('care', 0.0259616105570968),
#   ('scott', 0.024293319337182276),
#   ('hous', 0.018070030741546075),
#   ('polici', 0.0155582214890905),
#   ('action', 0.015501986953587763),
#   ('talk', 0.015089600359901027),
#   ('report', 0.014433530779035765),
#   ('ask', 0.013571267901327136),
#   ('secur', 0.01349628852065682),
#   ('elect', 0.013196370997975557),
#   ('power', 0.012652770488115769),
#   ('mp', 0.012071680287920822),
#   ('question', 0.011809252455574716),
#   ('age', 0.011528079778061032),
#   ('stand', 0.010178450925995352)],
#  3: [('…', 0.5396353067367912),
#   ('say', 0.056330230787862014),
#   ('would', 0.03473928237777239),
#   ('said', 0.023320992353205772),
#   ('doesnt', 0.016227812186429536),
#   ('campaign', 0.015812601640081657),
#   ('tell', 0.015362790214871459),
#   ('miss', 0.015293588457146812),
#   ('deserv', 0.013632746271755303),
#   ('less', 0.010830075083907131),
#   ('here', 0.0104840662952839),
#   ('didnt', 0.010380263658696931),
#   ('believ', 0.010068855748936022),
#   ('ye', 0.008996228504204007),
#   ('wrong', 0.008684820594443098),
#   ('problem', 0.008408013563544514),
#   ('matter', 0.00781979862288502),
#   ('piec', 0.00781979862288502),
#   ('massiv', 0.006504965226116743),
#   ('fall', 0.006089754679768866)],
#  4: [('bushfir', 0.06629748473242936),
#   ('fire', 0.05641237967084153),
#   ('nsw', 0.03902287547872891),
#   ('emerg', 0.03472725390746299),
#   ('volunt', 0.027429872683987166),
#   ('water', 0.018010557913259496),
#   ('effort', 0.01713073180830142),
#   ('defenc', 0.016820204947727978),
#   ('christma', 0.016613187040679017),
#   ('firefight', 0.01583686988924542),
#   ('island', 0.01531932512162302),
#   ('relief', 0.013973708725804782),
#   ('condit', 0.013197391574371184),
#   ('east', 0.012421074422937585),
#   ('season', 0.011178966980643825),
#   ('#youradf', 0.010350895352447986),
#   ('adf', 0.009885105061587827),
#   ('danger', 0.009781596108063348),
#   ('sa', 0.009574578201014388),
#   ('burn', 0.009419314770727667)],
#  5: [('today', 0.05178103054403926),
#   ('work', 0.03617057280649801),
#   ('support', 0.03480624418309502),
#   ('new', 0.03266985362551823),
#   ('commun', 0.02911625349014299),
#   ('great', 0.028767239191132922),
#   ('one', 0.0235214485151028),
#   ('good', 0.020158219815551232),
#   ('local', 0.017863186394788053),
#   ('week', 0.016139267281495895),
#   ('see', 0.015134529147982063),
#   ('well', 0.014299010068533716),
#   ('first', 0.013992300533040021),
#   ('take', 0.01388653862424909),
#   ('live', 0.01388653862424909),
#   ('back', 0.012955833826888908),
#   ('last', 0.012257805228868771),
#   ('‘', 0.012014552838649632),
#   ('come', 0.011771300448430493),
#   ('feder', 0.011602081394365006)],
#  6: [('sport', 0.03373004006937384),
#   ('taylor', 0.016207164643262963),
#   ('rort', 0.015609114287423),
#   ('press', 0.015549309251839005),
#   ('democraci', 0.013994378326655104),
#   ('angu', 0.013814963219903116),
#   ('robodebt', 0.013456133006399138),
#   ('skill', 0.013037497757311165),
#   ('victim', 0.011183541654207284),
#   ('freedom', 0.010525686262783326),
#   ('privatis', 0.00998744094252736),
#   ('scandal', 0.009449195622271395),
#   ('treat', 0.009449195622271395),
#   ('mckenzi', 0.009269780515519407),
#   ('tafe', 0.008970755337599426),
#   ('taxpay', 0.008193289875007476),
#   ('protest', 0.00813348483942348),
#   ('aid', 0.007894264697087495),
#   ('gap', 0.007714849590335506),
#   ('journalist', 0.00765504455475151)],
#  7: [('help', 0.04552129221732746),
#   ('servic', 0.03398923152227117),
#   ('import', 0.027880567792462067),
#   ('pleas', 0.019951052373959863),
#   ('continu', 0.019304943710230053),
#   ('industri', 0.015134605971610376),
#   ('across', 0.014684287812041116),
#   ('protect', 0.0142143906020558),
#   ('read', 0.013822809593734704),
#   ('stop', 0.01376407244248654),
#   ('centr', 0.01258932941752325),
#   ('everyon', 0.01247185511502692),
#   ('safe', 0.012334801762114538),
#   ('save', 0.011845325501713166),
#   ('ensur', 0.01168869309838473),
#   ('impact', 0.011512481644640235),
#   ('social', 0.010748898678414097),
#   ('close', 0.010533529123837494),
#   ('assist', 0.010533529123837494),
#   ('find', 0.010161527165932452)],
#  8: [('women', 0.03621224811548505),
#   ('happi', 0.030447849435877222),
#   ('club', 0.02300832635364832),
#   ('serv', 0.02295905798886535),
#   ('rememb', 0.022663447800167512),
#   ('turn', 0.02172734886929103),
#   ('queensland', 0.01847563679361482),
#   ('veteran', 0.018229294969699956),
#   ('war', 0.01502685125880672),
#   ('old', 0.014632704340542937),
#   ('birthday', 0.01414002069271321),
#   ('wish', 0.013450263585751588),
#   ('qld', 0.013351726856185643),
#   ('colleagu', 0.013253190126619697),
#   ('forget', 0.011676602453564566),
#   ('coast', 0.011479528994432674),
#   ('game', 0.010789771887471055),
#   ('north', 0.01069123515790511),
#   ('reflect', 0.008868305660935114),
#   ('mum', 0.007882938365275656)],
#  9: [('job', 0.08732222052301575),
#   ('👇', 0.04220828872916348),
#   ('school', 0.040564306468879034),
#   ('public', 0.0345618596115614),
#   ('welcom', 0.02660957332925524),
#   ('student', 0.020798287199877658),
#   ('educ', 0.020148340724881482),
#   ('young', 0.0198424835601774),
#   ('learn', 0.019039608502829177),
#   ('🏼', 0.018580822755773056),
#   ('decis', 0.017930876280776876),
#   ('earli', 0.017777947698424834),
#   ('employ', 0.016669215476372533),
#   ('check', 0.015522251108732222),
#   ('thousand', 0.015178161798440129),
#   ('leadership', 0.014184126013151858),
#   ('child', 0.014184126013151858),
#   ('left', 0.012846000917571494),
#   ('behind', 0.01154610796757914),
#   ('nurs', 0.011354947239639089)],
#  10: [('cut', 0.03990448824315027),
#   ('️', 0.035938322068881784),
#   ('tax', 0.02853211380468655),
#   ('billion', 0.025253956048403414),
#   ('growth', 0.022744748876927436),
#   ('rate', 0.02266380671010563),
#   ('emiss', 0.022340038042818405),
#   ('energi', 0.019952244121575136),
#   ('speech', 0.018576227285604437),
#   ('cost', 0.017443036950099154),
#   ('deal', 0.01473147436156866),
#   ('commiss', 0.013841110526528795),
#   ('low', 0.01266744910761261),
#   ('target', 0.012262738273503581),
#   ('budget', 0.01210085393985997),
#   ('price', 0.01197944068962726),
#   ('renew', 0.011210490104820106),
#   ('almost', 0.011048605771176494),
#   ('zero', 0.01044153952001295),
#   ('royal', 0.010077299769314825)],
#  11: [('drought', 0.04127414976848156),
#   ('🇺', 0.032332747884400444),
#   ('farmer', 0.03121507264889031),
#   ('award', 0.030656235031135237),
#   ('🇦', 0.028740220341689285),
#   ('disabl', 0.023231678109532174),
#   ('ndi', 0.019319814785246688),
#   ('particip', 0.018042471658949386),
#   ('#ndi', 0.016844962478045664),
#   ('tim', 0.016365958805684176),
#   ('flight', 0.011575922082069296),
#   ('citizen', 0.011336420245888552),
#   ('ceremoni', 0.010538080791952738),
#   ('tribut', 0.009021235829474693),
#   ('drug', 0.008701900047900368),
#   ('vale', 0.008622066102506785),
#   ('chines', 0.008542232157113205),
#   ('recipi', 0.008462398211719624),
#   ('jame', 0.007664058757783809),
#   ('quarter', 0.007264889030815903)],
#  12: [('worker', 0.17265364459266316),
#   ('wage', 0.10948070509766555),
#   ('subsidi', 0.05212005717008099),
#   ('unemploy', 0.029537875178656504),
#   ('lose', 0.022391615054787994),
#   ('vulner', 0.0222010481181515),
#   ('figur', 0.019437827536922345),
#   ('univers', 0.019342544068604098),
#   ('childcar', 0.017818008575512148),
#   ('racism', 0.01600762267746546),
#   ('ship', 0.014387803716055265),
#   ('labour', 0.014292520247737018),
#   ('virgin', 0.012577417818008576),
#   ('employe', 0.01248213434969033),
#   ('aviat', 0.010862315388280133),
#   ('airlin', 0.009528346831824679),
#   ('ab', 0.008480228680323963),
#   ('easter', 0.00828966174368747),
#   ('insecur', 0.007717960933777989),
#   ('cruis', 0.007717960933777989)],
#  13: [('australian', 0.04303551945690387),
#   ('australia', 0.03491332282700933),
#   ('year', 0.026444763867481774),
#   ('thank', 0.023717160521621667),
#   ('day', 0.02154373690317441),
#   ('nation', 0.02111944304937395),
#   ('minist', 0.017361411772855585),
#   ('govt', 0.014893580174220251),
#   ('us', 0.014547217844587223),
#   ('famili', 0.014036333408378504),
#   ('fund', 0.012157317770119322),
#   ('economi', 0.010919072441681242),
#   ('region', 0.01052075576260326),
#   ('look', 0.010009871326394542),
#   ('media', 0.00928251043416518),
#   ('econom', 0.008970784337495454),
#   ('state', 0.008901511871568847),
#   ('meet', 0.008814921289160591),
#   ('morn', 0.00869369447378903),
#   ('releas', 0.008338673085915176)],
#  14: [('parliament', 0.12340462228354605),
#   ('senat', 0.050620903759917214),
#   ('vote', 0.04467057606071059),
#   ('bill', 0.04423939289410141),
#   ('green', 0.03259744739565367),
#   ('incom', 0.03121766126250431),
#   ('gov', 0.03052776819592963),
#   ('resourc', 0.02423249396343567),
#   ('legisl', 0.021472921697136944),
#   ('debat', 0.021300448430493273),
#   ('parliamentari', 0.019661952397378408),
#   ('amend', 0.019575715764056572),
#   ('#qt', 0.019317005864091064),
#   ('push', 0.01733356329768886),
#   ('rd', 0.014229044498102795),
#   ('photo', 0.013711624698171783),
#   ('lift', 0.012418075198344257),
#   ('motion', 0.012073128665056916),
#   ('limit', 0.011900655398413246),
#   ('ga', 0.011555708865125906)],
#  15: [('visit', 0.06561134589212807),
#   ('project', 0.05028293102213308),
#   ('invest', 0.04154430198409856),
#   ('infrastructur', 0.03588568154143686),
#   ('indigen', 0.030585201633120836),
#   ('list', 0.02299262230499248),
#   ('cancer', 0.02048563856457274),
#   ('upgrad', 0.013322827877659194),
#   ('facil', 0.013036315450182651),
#   ('#', 0.012964687343313516),
#   ('patient', 0.012893059236444382),
#   ('g', 0.011747009526538213),
#   ('rail', 0.01117398467158513),
#   ('resili', 0.010672587923501183),
#   ('medicin', 0.010457703602893775),
#   ('#forthebeach', 0.01038607549602464),
#   ('loan', 0.010314447389155504),
#   ('relationship', 0.009813050641071557),
#   ('beach', 0.009311653892987609),
#   ('congest', 0.009168397679249337)],
#  16: [('health', 0.0603958965467418),
#   ('busi', 0.06025140875596012),
#   ('home', 0.0492342147088571),
#   ('keep', 0.04554977604392429),
#   ('million', 0.04110677647738766),
#   ('stay', 0.02333477821124115),
#   ('updat', 0.021311949140297645),
#   ('small', 0.020950729663343447),
#   ('packag', 0.02080624187256177),
#   ('inform', 0.020192168761739633),
#   ('payment', 0.018675046958532004),
#   ('sector', 0.017988729952319028),
#   ('advic', 0.017085681259933535),
#   ('test', 0.017013437364542697),
#   ('b', 0.016905071521456438),
#   ('step', 0.016290998410634302),
#   ('mental', 0.014521022973558735),
#   ('medic', 0.013979193758127438),
#   ('spread', 0.01090882820401676),
#   ('food', 0.010439242883976303)],
#  17: [('#tyfi', 0.06736794986571172),
#   ('•', 0.04051029543419875),
#   ('disast', 0.03995076096687556),
#   ('#lovegippsland', 0.03849597135183527),
#   ('app', 0.03424350940017905),
#   ('#bushfir', 0.024059982094897046),
#   ('download', 0.022829006266786033),
#   ('lake', 0.0182408236347359),
#   ('#ourveteran', 0.0173455684870188),
#   ('anzac', 0.016338406445837065),
#   ('covidsaf', 0.015778871978513877),
#   ('#regionsmatt', 0.01566696508504924),
#   ('gippsland', 0.015331244404655327),
#   ('commemor', 0.013764547896150402),
#   ('date', 0.012645478961504029),
#   ('#lestweforget', 0.010519247985675918),
#   ('arrang', 0.009623992837958818),
#   ('#waggawagga', 0.00951208594449418),
#   ('lest', 0.00906445837063563),
#   ('enlist', 0.008952551477170993)],
#  18: [('coronaviru', 0.19954128440366972),
#   ('#covid', 0.08551769331585846),
#   ('jobkeep', 0.07552424639580603),
#   ('#coronaviru', 0.07142857142857142),
#   ('casual', 0.061435124508519005),
#   ('#covidau', 0.05258846657929227),
#   ('pandem', 0.0491480996068152),
#   ('distanc', 0.0358781127129751),
#   ('covid', 0.033420707732634336),
#   ('viru', 0.027850589777195282),
#   ('restrict', 0.026703800786369594),
#   ('temporari', 0.02490170380078637),
#   ('#jobkeep', 0.02211664482306684),
#   ('outbreak', 0.01752948885976409),
#   ('jobseek', 0.01703800786369594),
#   ('#covidaustralia', 0.01687418086500655),
#   ('exclud', 0.015399737876802096),
#   ('vaccin', 0.012942332896461337),
#   ('#coronavirusau', 0.01261467889908257),
#   ('self-isol', 0.010812581913499346)]}

# %%
df_agg["bushfire_topic"] = df_agg["topic_dist"].apply(lambda row: row[4][1])

# %%
df_week = df_agg.groupby("party").resample('W-Mon', on='created_at').agg({"party":"first", "created_at":"first", "bushfire_topic":"mean"}).reset_index(drop = True)

# %%
df_week["party"].unique()
# Out:
# array(['Australian Greens', 'Australian Labor Party', 'Centre Alliance',
#        None, 'Independent', "Katter's Australian Party",
#        'Liberal National Party of Queensland',
#        'Liberal Party of Australia', 'Nick Xenophon Team',
#        'The Nationals'], dtype=object)

# %%
bliberals = df_week.loc[df_week["party"] == "Liberal Party of Australia"]
greens = df_week.loc[df_week["party"] == "Australian Greens"]
labor = df_week.loc[df_week["party"] == "Australian Labor Party"]
center = df_week.loc[df_week["party"] == "Centre Alliance"]


fig, ax = plt.subplots(figsize=(15, 10), dpi=200)
#plt.figure()
ax.plot(liberals["created_at"], liberals["bushfire_topic"], 'bo--', label = "Liberals")
ax.plot(labor["created_at"], labor["bushfire_topic"], 'r^--', label = "Labor")
ax.plot(greens["created_at"], greens["bushfire_topic"], 'g*--', label = "Greens")
ax.plot(center["created_at"], center["bushfire_topic"], 'y+--', label = "Center")
ax.set_ylabel("Bushfire Topic Proportion")

plt.legend()
plt.show()
fig.savefig("topic_prop.pdf")

# %% [markdown]
# # **LDA**

# %%
#Creating a corpus object 
corpus = [id2word.doc2bow(doc) for doc in df['stems']]

# %%
#Instantiating a logger to get information on the progress of the LDA
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

#Running the LDA with 23 topics 
lda_model = LdaMulticore(corpus=corpus, num_topics=23, id2word=id2word, passes = 100, iterations = 1000, alpha = "auto")

#Disabling logging
logging.disable(sys.maxsize)

# %%
#Creating a dataframe with tokens as columns and topics as rows 
beta_df = pd.DataFrame(lda_model.get_topics(), columns = list(id2word.token2id.keys()))

# %%
#Vizualising the 23 topics
topics = list(range(0, 22))

fig, axes = plt.subplots(ncols=5, nrows=5, figsize = (16,30)) 
fig.tight_layout(pad=8.0)
    
for ax, topic in zip(axes.flatten(), topics): #Iterates through the axes and the topics
    
    #Creates 20 barplots with x as the beta values and y as the words
    sns.barplot(ax = ax, 
                x = beta_df.iloc[topic].nlargest(10).values, 
                y = beta_df.iloc[topic].nlargest(10).index, 
                orient = 'h')
    
    ax.set(title='Topic {}'.format(topic), xlabel='beta')

plt.show()

# %%
#Insert the corpus of documents in bag of word format and get a list of (topic, probability) per document. 
document_topics = list(lda_model.get_document_topics(corpus)) 

#Creating a list of names for all 23 topics
topics = ['topic_{}'.format(t) for t in range(0,22)]

#Creating a dataframe of gamma probabilities 
gamma_probs = pd.DataFrame(np.zeros((len(document_topics),20)), columns = topics)

for i, doc in enumerate(document_topics): 
    for pair in doc: 
        gamma_probs.loc[i,'topic_{}'.format(pair[0])] = pair[1]

# %%
#Merging with the original dataframe 
df = pd.concat((df, gamma_probs), axis = 1)
