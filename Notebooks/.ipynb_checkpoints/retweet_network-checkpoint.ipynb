# %%
import networkx as nx
import pandas as pd
import numpy as np
from ast import literal_eval
import matplotlib.pyplot as plt
#from textnets import Corpus, Textnet
from fa2 import ForceAtlas2
from pyvis import network as net

# %%
pd.read_csv("data/final_df.csv")
# Out:
#         Unnamed: 0   screen_name             user_id      tweet_id  \
# 0                0   AlanTudgeMP           185932331  1.388275e+18
# 1                1   AlanTudgeMP           185932331  1.388274e+18
# 2                2   AlanTudgeMP           185932331  1.388039e+18
# 3                3   AlanTudgeMP           185932331  1.388035e+18
# 4                4   AlanTudgeMP           185932331  1.388031e+18
# ...            ...           ...                 ...           ...
# 170333      170333  P_Thompson88  929896339307053056  1.260309e+18
# 170334      170334  P_Thompson88  929896339307053056  1.260183e+18
# 170335      170335  P_Thompson88  929896339307053056  1.260103e+18
# 170336      170336  P_Thompson88  929896339307053056  1.187588e+18
# 170337      170337  P_Thompson88  929896339307053056  1.185691e+18
#
#         created_at                                          full_text  \
# 0       2021-04-30  Get the fundamentals right and lift our game. ...
# 1       2021-04-30  RT @australian: State and federal education mi...
# 2       2021-04-30  Great support for our $53m Higher Education su...
# 3       2021-04-30  RT @IndependentHEA: IHEA welcomes today’s anno...
# 4       2021-04-30  RT @ITECAust: The Australian — As @TimDoddEDU ...
# ...            ...                                                ...
# 170333  2020-05-12  REEF HQ FUNDING BOOST: We've just announced $2...
# 170334  2020-05-12  We've been doing so well at keeping COVID-19 a...
# 170335  2020-05-12  JOBKEEPER Q&amp;A: I've asked Assistant Treasu...
# 170336  2019-10-25  The people of Townsville are tired of being he...
# 170337  2019-10-19  Excellent catch-up with these two great Austra...
#
#         favorite_count  retweet_count in_reply_to_screen_name  \
# 0                 18.0            7.0                     NaN
# 1                  0.0            6.0                     NaN
# 2                 12.0            3.0                     NaN
# 3                  0.0            2.0                     NaN
# 4                  0.0            1.0                     NaN
# ...                ...            ...                     ...
# 170333             7.0            0.0                     NaN
# 170334             3.0            0.0                     NaN
# 170335             2.0            0.0                     NaN
# 170336           116.0           41.0                     NaN
# 170337             8.0            1.0                     NaN
#
#                     hashtags  \
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []
# ...                      ...
# 170333                    []
# 170334  ['TownsvilleStrong']
# 170335                    []
# 170336                    []
# 170337                    []
#
#                                             user_mentions  \
# 0                                                      []
# 1                                          ['australian']
# 2                                                      []
# 3       ['IndependentHEA', 'AlanTudgeMP', 'stuartrober...
# 4                              ['ITECAust', 'TimDoddEDU']
# ...                                                   ...
# 170333                                 ['reefhqaquarium']
# 170334                                                 []
# 170335                                                 []
# 170336                                                 []
# 170337                      ['PeterDutton_MP', 'PMOnAir']
#
#                                                       url  image_url  \
# 0       https://www.theaustralian.com.au/inquirer/get-...        NaN
# 1                                                     NaN        NaN
# 2       https://twitter.com/ITECAust/status/1387941814...        NaN
# 3                                                     NaN        NaN
# 4                                                     NaN        NaN
# ...                                                   ...        ...
# 170333  https://www.philthompson.com.au/media-release-...        NaN
# 170334  https://www.philthompson.com.au/media-release-...        NaN
# 170335            http://philthompson.com.au/teletownhall        NaN
# 170336                                                NaN        NaN
# 170337                                                NaN        NaN
#
#                     name                                 party  \
# 0             Alan Tudge            Liberal Party of Australia
# 1             Alan Tudge            Liberal Party of Australia
# 2             Alan Tudge            Liberal Party of Australia
# 3             Alan Tudge            Liberal Party of Australia
# 4             Alan Tudge            Liberal Party of Australia
# ...                  ...                                   ...
# 170333  Phillip Thompson  Liberal National Party of Queensland
# 170334  Phillip Thompson  Liberal National Party of Queensland
# 170335  Phillip Thompson  Liberal National Party of Queensland
# 170336  Phillip Thompson  Liberal National Party of Queensland
# 170337  Phillip Thompson  Liberal National Party of Queensland
#
#         legislative_period                                             lemmas  \
# 0                       46  get fundamental right lift game see thought pr...
# 1                       46  state federal education minister set oppose el...
# 2                       46       great support high education support package
# 3                       46  ihea welcome todays announcement unveil suite ...
# 4                       46  australian report iteca welcome australian gov...
# ...                    ...                                                ...
# 170333                  46  reef hq funding boost weve announce extra fund...
# 170334                  46  weve well keep covid - bay townsville cant tak...
# 170335                  46  jobkeeper qa ive ask assistant treasurer micha...
# 170336                  46  people townsville tire hold hostage city kid c...
# 170337                  46            excellent catch-up two great australian
#
#                                                     stems  \
# 0       get fundament right lift game see thought prio...
# 1       state feder educ minist set oppos element prop...
# 2                great support higher educ support packag
# 3       ihea welcom today announc unveil suit budget m...
# 4       australian report iteca welcom australian gove...
# ...                                                   ...
# 170333  reef hq fund boost weve announc extra fund imp...
# 170334  weve well keep covid - bay townsvil cant take ...
# 170335  jobkeep qa ive ask assist treasur michael sukk...
# 170336  peopl townsvil tire held hostag citi kid crimi...
# 170337                excel catch-up two great australian
#
#                                                pos_lemmas  \
# 0                    lift game priority curriculum review
# 1       state education minister element school curric...
# 2                       support education support package
# 3             welcome announcement suite budget measure …
# 4                             report government support …
# ...                                                   ...
# 170333  reef hq funding boost announce funding tourism...
# 170334  covid bay townsville anything fund dedicate re...
# 170335  jobkeeper qa ask assistant treasurer michael b...
# 170336  tire hold hostage city take advantage annastac...
# 170337                                                NaN
#
#                                                 pos_stems
# 0                           game nation curriculum review
# 1       state feder minist element school curriculum b...
# 2                                  support support packag
# 3           ihea welcom today suit budget measur provid …
# 4                    report iteca welcom support provid …
# ...                                                   ...
# 170333  reef hq fund boost announc fund improv tourism...
# 170334  covid bay townsvil grant fund respiratori see ...
# 170335  jobkeep qa ask assist treasur michael busi own...
# 170336  peopl townsvil tire citi kid annastacia palasz...
# 170337                                                NaN
#
# [170338 rows x 20 columns]

# %%
path = "data/final_df.csv"

def retweet_df(df_path):
    df = pd.read_csv(df_path, index_col=0)
    df = df[["screen_name", "name", "party", "created_at", "user_mentions"]]
    df = df.dropna(subset=["user_mentions"])
    df['user_mentions'] = df['user_mentions'].apply(literal_eval) #convert to list type
    df = df.explode("user_mentions")
    df = df.loc[df["user_mentions"].isin(df["screen_name"])].reset_index(drop = True)
    df = df.groupby(["screen_name", "user_mentions"]).size().reset_index(name = "count")
    
    return df

retweet_df = retweet_df(path)

# %%
#retweet_df = retweet_df.dropna(subset = ["user_mentions"])

# %% [markdown]
# ## Create Retweet Network

# %%
G = nx.from_pandas_edgelist(
    retweet_df,
    source = "screen_name",
    target = "user_mentions",
    edge_attr="count", 
    create_using=nx.DiGraph())

# %%
#id_c = dict(nx.in_degree_centrality(G))#.values

# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.2,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2.0,
                        strongGravityMode=False,
                        gravity=1.0,

                        # Log
                        verbose=True)

# %%
plt.figure(dpi=200, figsize = (15,8))

pos = forceatlas2.forceatlas2_networkx_layout(G)

options = {
    'node_color': 'red',
    'width': 0.5,
    'alpha':0.4,
    'with_labels':True,
    'pos':pos,}
    #'node_size':[s*100 for s in id_c.values()]
   # }

nx.draw(G, **options)
plt.show()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1773.42it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.04  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds

# %%
# Create nodelist
a1 = retweet_df["screen_name"].tolist()
a2 = retweet_df["user_mentions"].tolist()
node_list = list(set(a1 + a2))

# Edgedata as tuples
tuples = [tuple(x) for x in retweet_df[["screen_name","user_mentions", "count"]].values]

# Create network
nt = net.Network(notebook=True,
                     height = "700px",
                     width = "700px",
                     bgcolor = "#f6f2e9")

# Add nodes and edges to network
for i in node_list:
    nt.add_node(i, title=i)
nt.add_edges(tuples)

nt.force_atlas_2based()

# Save and show
nt.show('retweet_network.html')
# Out:
#         <iframe
#             width="700px"
#             height="700px"
#             src="retweet_network.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
