# %% [markdown]
# # Principal Component Analysis

# %%
# import packages
import pandas as pd 
import numpy as np

# %%
# get lemmatized data: 
final_df = pd.read_csv("data/final_df.csv")

# %%
final_df.head()
# Out:
#    Unnamed: 0  screen_name    user_id      tweet_id  created_at  \
# 0           0  AlanTudgeMP  185932331  1.388275e+18  2021-04-30
# 1           1  AlanTudgeMP  185932331  1.388274e+18  2021-04-30
# 2           2  AlanTudgeMP  185932331  1.388039e+18  2021-04-30
# 3           3  AlanTudgeMP  185932331  1.388035e+18  2021-04-30
# 4           4  AlanTudgeMP  185932331  1.388031e+18  2021-04-30
#
#                                            full_text  favorite_count  \
# 0  Get the fundamentals right and lift our game. ...            18.0
# 1  RT @australian: State and federal education mi...             0.0
# 2  Great support for our $53m Higher Education su...            12.0
# 3  RT @IndependentHEA: IHEA welcomes today’s anno...             0.0
# 4  RT @ITECAust: The Australian — As @TimDoddEDU ...             0.0
#
#    retweet_count in_reply_to_screen_name hashtags  \
# 0            7.0                     NaN       []
# 1            6.0                     NaN       []
# 2            3.0                     NaN       []
# 3            2.0                     NaN       []
# 4            1.0                     NaN       []
#
#                                        user_mentions  \
# 0                                                 []
# 1                                     ['australian']
# 2                                                 []
# 3  ['IndependentHEA', 'AlanTudgeMP', 'stuartrober...
# 4                         ['ITECAust', 'TimDoddEDU']
#
#                                                  url  image_url        name  \
# 0  https://www.theaustralian.com.au/inquirer/get-...        NaN  Alan Tudge
# 1                                                NaN        NaN  Alan Tudge
# 2  https://twitter.com/ITECAust/status/1387941814...        NaN  Alan Tudge
# 3                                                NaN        NaN  Alan Tudge
# 4                                                NaN        NaN  Alan Tudge
#
#                         party  legislative_period  \
# 0  Liberal Party of Australia                  46
# 1  Liberal Party of Australia                  46
# 2  Liberal Party of Australia                  46
# 3  Liberal Party of Australia                  46
# 4  Liberal Party of Australia                  46
#
#                                           lemma_text  \
# 0  get fundamental right lift game see thought pr...
# 1  state federal education minister set oppose el...
# 2       great support high education support package
# 3  ihea welcome todays announcement unveil suite ...
# 4  australian report iteca welcome australian gov...
#
#                                         stemmed_text  \
# 0  get fundament right lift game see thought prio...
# 1  state feder educ minist set oppos element prop...
# 2           great support higher educ support packag
# 3  ihea welcom today announc unveil suit budget m...
# 4  australian report iteca welcom australian gove...
#
#                                       lemma_text_sub  \
# 0  ['lift', 'game', 'priority', 'curriculum', 're...
# 1  ['state', 'education', 'minister', 'element', ...
# 2     ['support', 'education', 'support', 'package']
# 3  ['welcome', 'announcement', 'suite', 'budget',...
# 4           ['report', 'government', 'support', '…']
#
#                                     stemmed_text_sub
# 0         ['game', 'nation', 'curriculum', 'review']
# 1  ['state', 'feder', 'minist', 'element', 'schoo...
# 2                   ['support', 'support', 'packag']
# 3  ['ihea', 'welcom', 'today', 'suit', 'budget', ...
# 4  ['report', 'iteca', 'welcom', 'support', 'prov...

# %% [markdown]
# ## Identify local word associations

# %%
### Identify whether each word appear in each tweet or not
# The column proc_text holds the preprocessed tweet
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
vectorizer = CountVectorizer(ngram_range=(1,1)) # Instantiante the counting class
doc2type = vectorizer.fit_transform(final_df.lemma_text_sub) # Count the number of times each word type appear in each tweet
doc2type[doc2type>0] = 1 # Restrict count to 1, i.e. we get the tweet-frequency of each word (how many tweets it appear in) 
type_names = np.array(vectorizer.get_feature_names()) # Get the sequence of words according to how they are counted
n_docs, n_types = doc2type.shape
