# %% [markdown]
# <a href="https://colab.research.google.com/github/frederik-kilpinen/ASDS2/blob/main/Notebooks/topic_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk==3.4
# Out:
# Requirement already satisfied: nltk==3.4 in /usr/local/lib/python3.7/dist-packages (3.4)
# Requirement already satisfied: singledispatch in /usr/local/lib/python3.7/dist-packages (from nltk==3.4) (3.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.4) (1.15.0)

# %%
#Importing erlevant packages 
import numpy as np
import pandas as pd
from datetime import datetime 
from tqdm import tqdm 
import logging 
import sys 
import pickle 
import requests
import io

#Importing NLTK and NLP packages
import nltk
from nltk.tokenize import TweetTokenizer
import string
import re
from collections import defaultdict

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')

#Importing packages for data visualization 
import matplotlib.pyplot as plt
import seaborn as sns

#Importing packages for LDA
from gensim.corpora.dictionary import Dictionary
from gensim.models.ldamulticore import LdaMulticore
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Importing and viewing data
tweets = pd.read_csv("/content/drive/MyDrive/Digital methods/final_tweet_df")

# %%
# Subsetting data (should be removed with new dataset)
tweets.loc[(tweets["created_at"] >= "2018-06-01") & (tweets["created_at"] <= "2021-05-01")]
# Out:
#         Unnamed: 0  ... lp.official_legislative_period
# 16              16  ...                             46
# 17              17  ...                             46
# 18              18  ...                             46
# 19              19  ...                             46
# 20              20  ...                             46
# ...            ...  ...                            ...
# 299035      299035  ...                             46
# 299036      299036  ...                             46
# 299037      299037  ...                             46
# 299038      299038  ...                             46
# 299039      299039  ...                             46
#
# [170514 rows x 17 columns]

# %%
#Reusing and tweaking the function for preprocessing from last week to fit specifics of this dataset.
def preprocess(text):
    
    #Lowercasing words
    text = str(text)
    text = text.lower()
    
    #Removing '&amp' which was found to be common
    text = re.sub(r'&amp','', text)
    
    #Replace other instances of "&" with "and"
    text = re.sub(r'&','and', text)
    
    #Removing mentions 
    text = re.sub(r'@\w+ ', '', text)
    
    #Removing 'RT' and 'via'
    text = re.sub(r'(^rt|^via)((?:\b\W*@\w+)+): ', '', text)
    
    #Removing punctuation
    my_punctuation = string.punctuation.replace('#','')
    my_punctuation = my_punctuation.replace('-','')
    
    text = text.translate(str.maketrans('', '', my_punctuation))
    text = re.sub(r' - ','', text) #removing dash lines bounded by whitespace (and therefore not part of a word)
    text = re.sub(r'[’“”—,!]','',text) #removing punctuation that is not captured by string.punctuation
    
    #Removing odd special characters
    text = re.sub(r"[┻┃━┳┓┏┛┗]","", text)
    text = re.sub(r"\u202F|\u2069|\u200d|\u2066","", text)
    
    #Removing URLs
    text = re.sub(r'http\S+', '', text)
    
    #Removing numbers
    text = re.sub(r'[0-9]','', text)
    
    #Removing separators and superfluous whitespace
    text = text.strip()
    text = re.sub(r' +',' ',text)
    
    #Tokenizing
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    
    return tokens
    

def preprocess_lemma(tokens):
    
    #Running the preprocess function
    tokens = preprocess(tokens)
    
    #Lemmatizing
    tag_map = defaultdict(lambda : nltk.corpus.wordnet.NOUN)      #POS map
    tag_map['J'] = nltk.corpus.wordnet.ADJ
    tag_map['V'] = nltk.corpus.wordnet.VERB
    tag_map['R'] = nltk.corpus.wordnet.ADV    
    
    lemmatizer = nltk.WordNetLemmatizer()             #Creating lemmatizer.
    text_lemmatized = []                              #Empty list to save lemmatized sentence

    for word, tag in nltk.pos_tag(tokens):
        lemma = lemmatizer.lemmatize(word, tag_map[tag[0]])
        text_lemmatized.append(lemma)
    
    tokens = text_lemmatized

    #Removing stopwords
    stop_words_list = nltk.corpus.stopwords.words("english")
    text = " ".join([i for i in tokens if i not in stop_words_list])
    
    return text

def preprocess_stem(tokens):
    
    #Running the preprocess function
    tokens = preprocess(tokens)
    
    #Removing stopwords
    stop_words_list = nltk.corpus.stopwords.words("english")
    tokens = [i for i in tokens if i not in stop_words_list]
    
    #Stemming
    stemmer = nltk.PorterStemmer()    #Creating stemmer
    sent_stemmed = []                 #Empty list to save stemmed sentence
    
    for word in tokens:
        stem = stemmer.stem(word)     #Stemming words
        sent_stemmed.append(stem)
        
    tokens = sent_stemmed
    
    return " ".join(tokens)

# %%
# Lemmatizing tweets
tweets["text_lemmatized"] = tweets.full_text.apply(lambda x: preprocess_lemma(x))

# Stemming tweets
tweets["text_stemmed"] = tweets.full_text.apply(lambda x: preprocess_stem(x))

# %%
#Replacing nan values with empty strings
tweets.text_lemmatized = tweets.text_lemmatized.apply(lambda x: '' if str(x) == 'nan' else x)
tweets.text_stemmed = tweets.text_stemmed.apply(lambda x: '' if str(x) == 'nan' else x)

# %%
#Aggregating tweet data by dates and party 
tweets_agg = tweets.groupby(['created_at', 'p.party'], as_index = False).agg({'full_text': ' '.join,
                                                                            'text_lemmatized': ' '.join,
                                                                            'text_stemmed': ' '.join})

# %%
#Defining NLTK's TweetTokenizer
tokenizer = TweetTokenizer()

tqdm.pandas()

#Creating a column of unigrams from the stemmed tweet text
tweets_agg['unigrams'] = tweets_agg['text_stemmed'].progress_apply(lambda x: tokenizer.tokenize(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 14369/14369 [00:09<00:00, 1516.06it/s]

# %%
#5 Create bigrams from the unigrams
tweets_agg["bigrams"] = tweets_agg["unigrams"].apply(lambda x: list(nltk.bigrams(x)))

#Custom function to join the tuples of bigrams by an underscore
def join_tups(lst):
    return ['_'.join(tup) for tup in lst]

tweets_agg["bigrams"] = tweets_agg["bigrams"].apply(lambda x: join_tups(x))

# %%
#Create a id2word dictionary
tweets_agg['tokens'] = tweets_agg['unigrams'] + tweets_agg['bigrams']

#Insert the column where you saved unigram and bigram tokens between the parentheses
id2word = Dictionary(tweets_agg['tokens']) 

#Removing very frequent and infrequent words
id2word.filter_extremes(no_below=10, no_above=.999, keep_n = None)

#Creating a corpus object 
corpus = [id2word.doc2bow(doc) for doc in tweets_agg['tokens']]

# %% [markdown]
# # **Topic modelling**

# %%
#Instantiating a logger to get information on the progress of the LDA
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

#Running the LDA with 20 topics 
lda_model = LdaMulticore(corpus=corpus, num_topics=20, id2word=id2word, passes = 100, iterations = 1000) # should be changed to passes = 100, iterations = 1000

#Disabling logging
logging.disable(sys.maxsize)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2021-05-18 15:37:09,386 : INFO : topic #4 (0.050): 0.025*"#auspol" + 0.023*"morrison" + 0.017*"scott" + 0.015*"scott_morrison" + 0.013*"climat" + 0.011*"pm" + 0.010*"need" + 0.009*"#polita" + 0.008*"coal" + 0.007*"govern"
# 2021-05-18 15:37:09,391 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.007*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:37:09,397 : INFO : topic #18 (0.050): 0.012*"great" + 0.011*"today" + 0.010*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.005*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:37:09,408 : INFO : topic #15 (0.050): 0.013*"fund" + 0.012*"budget" + 0.012*"tax" + 0.011*"million" + 0.011*"plan" + 0.011*"new" + 0.011*"govern" + 0.009*"year" + 0.009*"announc" + 0.008*"invest"
# 2021-05-18 15:37:09,423 : INFO : topic diff=0.157667, rho=0.179073
# 2021-05-18 15:37:09,431 : INFO : PROGRESS: pass 23, dispatched chunk #3 = documents up to #8000/14369, outstanding queue size 3
# 2021-05-18 15:37:12,199 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:12,407 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"parliament" + 0.005*"govt" + 0.005*"australia" + 0.004*"peopl" + 0.004*"need"
# 2021-05-18 15:37:12,418 : INFO : topic #3 (0.050): 0.019*"servic" + 0.013*"support" + 0.010*"#ndi" + 0.010*"australian" + 0.008*"provid" + 0.008*"particip" + 0.008*"ndi" + 0.007*"assist" + 0.006*"deliv" + 0.006*"year"
# 2021-05-18 15:37:12,424 : INFO : topic #9 (0.050): 0.055*"…" + 0.015*"govern" + 0.014*"morrison" + 0.014*"#auspol" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"care" + 0.006*"liber" + 0.005*"minist"
# 2021-05-18 15:37:12,432 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.008*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.005*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:37:12,439 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"-" + 0.009*"australian" + 0.009*"help" + 0.008*"coronaviru" + 0.008*"bushfir" + 0.007*"keep" + 0.006*"covid_-"
# 2021-05-18 15:37:12,448 : INFO : topic diff=0.130707, rho=0.179073
# 2021-05-18 15:37:12,454 : INFO : PROGRESS: pass 23, dispatched chunk #4 = documents up to #10000/14369, outstanding queue size 3
# 2021-05-18 15:37:16,294 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:16,604 : INFO : topic #11 (0.050): 0.021*"#tyfi" + 0.018*"region" + 0.008*"year" + 0.008*"#youradf" + 0.008*"birthday" + 0.008*"servic" + 0.008*"happi" + 0.007*"serv" + 0.007*"commun" + 0.007*"help"
# 2021-05-18 15:37:16,626 : INFO : topic #9 (0.050): 0.055*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.014*"morrison" + 0.008*"scott" + 0.008*"australian" + 0.007*"scott_morrison" + 0.007*"care" + 0.006*"liber" + 0.005*"minist"
# 2021-05-18 15:37:16,639 : INFO : topic #7 (0.050): 0.024*"…" + 0.014*"australia" + 0.012*"australian" + 0.010*"🇺" + 0.009*"🇦" + 0.009*"🇦_🇺" + 0.008*"today" + 0.007*"️" + 0.007*"support" + 0.007*"job"
# 2021-05-18 15:37:16,652 : INFO : topic #4 (0.050): 0.027*"#auspol" + 0.022*"morrison" + 0.016*"scott" + 0.014*"scott_morrison" + 0.013*"climat" + 0.012*"#polita" + 0.011*"pm" + 0.010*"need" + 0.008*"coal" + 0.007*"govern"
# 2021-05-18 15:37:16,662 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"australian" + 0.009*"-" + 0.009*"help" + 0.008*"bushfir" + 0.007*"coronaviru" + 0.007*"keep" + 0.006*"work"
# 2021-05-18 15:37:16,666 : INFO : topic diff=0.122750, rho=0.179073
# 2021-05-18 15:37:16,675 : INFO : PROGRESS: pass 23, dispatched chunk #5 = documents up to #12000/14369, outstanding queue size 3
# 2021-05-18 15:37:21,460 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:22,143 : INFO : topic #5 (0.050): 0.016*"labor" + 0.015*"vote" + 0.012*"elect" + 0.011*"#ausvot" + 0.009*"thank" + 0.008*"#auspol" + 0.008*"liber" + 0.007*"campaign" + 0.007*"get" + 0.006*"go"
# 2021-05-18 15:37:22,145 : INFO : topic #4 (0.050): 0.029*"#auspol" + 0.021*"morrison" + 0.015*"scott" + 0.015*"#polita" + 0.013*"scott_morrison" + 0.012*"climat" + 0.011*"pm" + 0.010*"need" + 0.009*"#auspol_#polita" + 0.008*"coal"
# 2021-05-18 15:37:22,160 : INFO : topic #10 (0.050): 0.030*"…" + 0.008*"parliament" + 0.007*"time" + 0.006*"pm" + 0.006*"➡" + 0.005*"question" + 0.005*"look" + 0.005*"one" + 0.004*"ask" + 0.004*"minist"
# 2021-05-18 15:37:22,165 : INFO : topic #7 (0.050): 0.024*"…" + 0.013*"australia" + 0.012*"🇺" + 0.012*"australian" + 0.011*"🇦" + 0.010*"🇦_🇺" + 0.008*"today" + 0.007*"️" + 0.007*"job" + 0.007*"support"
# 2021-05-18 15:37:22,173 : INFO : topic #12 (0.050): 0.020*"turnbul" + 0.017*"cut" + 0.014*"labor" + 0.013*"…" + 0.012*"#auspol" + 0.008*"school" + 0.007*"abbott" + 0.007*"today" + 0.006*"fund" + 0.006*"tafe"
# 2021-05-18 15:37:22,179 : INFO : topic diff=0.093644, rho=0.179073
# 2021-05-18 15:37:22,185 : INFO : PROGRESS: pass 23, dispatched chunk #6 = documents up to #14000/14369, outstanding queue size 3
# 2021-05-18 15:37:30,296 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:30,479 : INFO : topic #9 (0.050): 0.057*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.012*"morrison" + 0.008*"australian" + 0.007*"scott" + 0.007*"care" + 0.007*"scott_morrison" + 0.006*"liber" + 0.005*"minist"
# 2021-05-18 15:37:30,485 : INFO : topic #13 (0.050): 0.023*"…" + 0.010*"veteran" + 0.010*"women" + 0.009*"peopl" + 0.007*"today" + 0.006*"royal" + 0.006*"nation" + 0.005*"commiss" + 0.005*"suicid" + 0.005*"royal_commiss"
# 2021-05-18 15:37:30,493 : INFO : topic #17 (0.050): 0.012*"australia" + 0.012*"tax" + 0.011*"busi" + 0.011*"australian" + 0.011*"great" + 0.008*"small" + 0.007*"citizen" + 0.007*"small_busi" + 0.006*"famili" + 0.006*"day"
# 2021-05-18 15:37:30,505 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.008*"local" + 0.008*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.006*"meet" + 0.006*"coast" + 0.005*"morn"
# 2021-05-18 15:37:30,511 : INFO : topic #2 (0.050): 0.021*"great" + 0.014*"day" + 0.012*"thank" + 0.010*"today" + 0.008*"commun" + 0.008*"year" + 0.007*"celebr" + 0.005*"morn" + 0.005*"good" + 0.005*"…"
# 2021-05-18 15:37:30,532 : INFO : topic diff=0.116488, rho=0.179073
# 2021-05-18 15:37:30,536 : INFO : PROGRESS: pass 23, dispatched chunk #7 = documents up to #14369/14369, outstanding queue size 3
# 2021-05-18 15:37:38,570 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:38,794 : INFO : topic #0 (0.050): 0.025*"servic" + 0.019*"day" + 0.014*"honour" + 0.013*"anzac" + 0.011*"rememb" + 0.009*"commemor" + 0.009*"war" + 0.009*"today" + 0.009*"memori" + 0.008*"serv"
# 2021-05-18 15:37:38,810 : INFO : topic #13 (0.050): 0.023*"…" + 0.010*"women" + 0.009*"veteran" + 0.009*"peopl" + 0.007*"today" + 0.006*"royal" + 0.006*"nation" + 0.006*"suicid" + 0.005*"commiss" + 0.005*"australian"
# 2021-05-18 15:37:38,818 : INFO : topic #14 (0.050): 0.019*"morrison" + 0.014*"👇" + 0.011*"…" + 0.010*"govern" + 0.009*"morrison_govern" + 0.008*"australian" + 0.006*"care" + 0.006*"women" + 0.006*"year" + 0.006*"need"
# 2021-05-18 15:37:38,827 : INFO : topic #5 (0.050): 0.018*"labor" + 0.016*"vote" + 0.013*"elect" + 0.010*"liber" + 0.009*"#ausvot" + 0.008*"thank" + 0.008*"#auspol" + 0.007*"campaign" + 0.007*"get" + 0.006*"go"
# 2021-05-18 15:37:38,838 : INFO : topic #12 (0.050): 0.021*"turnbul" + 0.018*"cut" + 0.015*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"great" + 0.006*"tax"
# 2021-05-18 15:37:38,852 : INFO : topic diff=0.109691, rho=0.179073
# 2021-05-18 15:37:46,606 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:46,752 : INFO : topic #18 (0.050): 0.012*"great" + 0.011*"today" + 0.010*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.005*"meet" + 0.005*"morn" + 0.005*"commun"
# 2021-05-18 15:37:46,755 : INFO : topic #10 (0.050): 0.031*"…" + 0.008*"➡" + 0.007*"parliament" + 0.007*"time" + 0.005*"pm" + 0.005*"question" + 0.005*"one" + 0.005*"look" + 0.004*"ask" + 0.004*"minist"
# 2021-05-18 15:37:46,768 : INFO : topic #17 (0.050): 0.013*"australia" + 0.012*"australian" + 0.011*"busi" + 0.010*"tax" + 0.010*"great" + 0.008*"small" + 0.007*"citizen" + 0.007*"small_busi" + 0.007*"day" + 0.006*"famili"
# 2021-05-18 15:37:46,778 : INFO : topic #12 (0.050): 0.020*"turnbul" + 0.018*"cut" + 0.015*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"great" + 0.006*"tax"
# 2021-05-18 15:37:46,781 : INFO : topic #9 (0.050): 0.055*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.007*"scott" + 0.007*"liber" + 0.007*"care" + 0.007*"scott_morrison" + 0.005*"need"
# 2021-05-18 15:37:46,788 : INFO : topic diff=0.148165, rho=0.179073
# 2021-05-18 15:37:48,190 : INFO : merging changes from 369 documents into a model of 14369 documents
# 2021-05-18 15:37:48,320 : INFO : topic #10 (0.050): 0.031*"…" + 0.008*"parliament" + 0.007*"time" + 0.006*"pm" + 0.006*"➡" + 0.005*"question" + 0.005*"one" + 0.005*"ask" + 0.004*"look" + 0.004*"minist"
# 2021-05-18 15:37:48,322 : INFO : topic #13 (0.050): 0.023*"…" + 0.011*"veteran" + 0.009*"peopl" + 0.009*"women" + 0.007*"today" + 0.006*"suicid" + 0.006*"royal" + 0.005*"nation" + 0.005*"commiss" + 0.005*"royal_commiss"
# 2021-05-18 15:37:48,329 : INFO : topic #9 (0.050): 0.055*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.014*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"care" + 0.007*"liber" + 0.006*"minist"
# 2021-05-18 15:37:48,349 : INFO : topic #5 (0.050): 0.016*"labor" + 0.015*"vote" + 0.012*"elect" + 0.009*"liber" + 0.008*"thank" + 0.008*"#auspol" + 0.007*"campaign" + 0.007*"get" + 0.006*"parti" + 0.006*"go"
# 2021-05-18 15:37:48,361 : INFO : topic #12 (0.050): 0.019*"turnbul" + 0.018*"cut" + 0.015*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"great" + 0.006*"tax"
# 2021-05-18 15:37:48,364 : INFO : topic diff=0.216938, rho=0.179073
# 2021-05-18 15:37:50,437 : INFO : -8.461 per-word bound, 352.3 perplexity estimate based on a held-out corpus of 369 documents with 270152 words
# 2021-05-18 15:37:50,440 : INFO : PROGRESS: pass 24, dispatched chunk #0 = documents up to #2000/14369, outstanding queue size 1
# 2021-05-18 15:37:50,513 : INFO : PROGRESS: pass 24, dispatched chunk #1 = documents up to #4000/14369, outstanding queue size 2
# 2021-05-18 15:37:50,645 : INFO : PROGRESS: pass 24, dispatched chunk #2 = documents up to #6000/14369, outstanding queue size 3
# 2021-05-18 15:37:52,810 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:52,995 : INFO : topic #3 (0.050): 0.020*"servic" + 0.014*"support" + 0.010*"#ndi" + 0.010*"australian" + 0.009*"provid" + 0.009*"particip" + 0.008*"ndi" + 0.007*"assist" + 0.006*"deliv" + 0.006*"disast"
# 2021-05-18 15:37:52,999 : INFO : topic #17 (0.050): 0.012*"australia" + 0.011*"australian" + 0.010*"great" + 0.010*"busi" + 0.010*"tax" + 0.007*"citizen" + 0.007*"small" + 0.007*"famili" + 0.007*"aussi" + 0.006*"day"
# 2021-05-18 15:37:53,003 : INFO : topic #10 (0.050): 0.031*"…" + 0.008*"parliament" + 0.007*"time" + 0.006*"pm" + 0.006*"➡" + 0.006*"question" + 0.005*"one" + 0.005*"look" + 0.005*"ask" + 0.004*"minist"
# 2021-05-18 15:37:53,006 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.005*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:37:53,008 : INFO : topic #0 (0.050): 0.024*"servic" + 0.018*"day" + 0.013*"anzac" + 0.013*"honour" + 0.011*"rememb" + 0.009*"war" + 0.009*"commemor" + 0.009*"today" + 0.008*"forget" + 0.008*"serv"
# 2021-05-18 15:37:53,012 : INFO : topic diff=0.154995, rho=0.176269
# 2021-05-18 15:37:53,025 : INFO : PROGRESS: pass 24, dispatched chunk #3 = documents up to #8000/14369, outstanding queue size 3
# 2021-05-18 15:37:55,961 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:37:56,119 : INFO : topic #14 (0.050): 0.019*"morrison" + 0.012*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.007*"jobkeep" + 0.006*"care" + 0.006*"need" + 0.006*"women"
# 2021-05-18 15:37:56,123 : INFO : topic #3 (0.050): 0.020*"servic" + 0.013*"support" + 0.010*"#ndi" + 0.009*"australian" + 0.008*"provid" + 0.008*"particip" + 0.008*"ndi" + 0.007*"assist" + 0.006*"deliv" + 0.006*"year"
# 2021-05-18 15:37:56,125 : INFO : topic #12 (0.050): 0.018*"cut" + 0.016*"turnbul" + 0.014*"labor" + 0.013*"…" + 0.012*"#auspol" + 0.008*"school" + 0.008*"abbott" + 0.007*"today" + 0.006*"fund" + 0.006*"great"
# 2021-05-18 15:37:56,128 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.007*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:37:56,130 : INFO : topic #16 (0.050): 0.012*"home" + 0.009*"super" + 0.007*"use" + 0.007*"australian" + 0.007*"covid" + 0.007*"australia" + 0.007*"‘" + 0.006*"save" + 0.006*"medic" + 0.006*"econom"
# 2021-05-18 15:37:56,139 : INFO : topic diff=0.128554, rho=0.176269
# 2021-05-18 15:37:56,147 : INFO : PROGRESS: pass 24, dispatched chunk #4 = documents up to #10000/14369, outstanding queue size 3
# 2021-05-18 15:37:59,752 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:00,344 : INFO : topic #17 (0.050): 0.012*"australia" + 0.011*"australian" + 0.011*"great" + 0.011*"busi" + 0.010*"tax" + 0.007*"small" + 0.007*"citizen" + 0.007*"famili" + 0.006*"small_busi" + 0.006*"aussi"
# 2021-05-18 15:38:00,353 : INFO : topic #9 (0.050): 0.055*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.014*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"care" + 0.007*"liber" + 0.005*"minist"
# 2021-05-18 15:38:00,359 : INFO : topic #5 (0.050): 0.016*"labor" + 0.015*"vote" + 0.012*"elect" + 0.009*"thank" + 0.008*"liber" + 0.008*"#auspol" + 0.007*"campaign" + 0.007*"get" + 0.006*"go" + 0.006*"parti"
# 2021-05-18 15:38:00,366 : INFO : topic #12 (0.050): 0.017*"cut" + 0.016*"turnbul" + 0.014*"labor" + 0.013*"…" + 0.012*"#auspol" + 0.010*"abbott" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"great"
# 2021-05-18 15:38:00,369 : INFO : topic #16 (0.050): 0.012*"home" + 0.009*"super" + 0.007*"use" + 0.007*"australian" + 0.007*"australia" + 0.007*"covid" + 0.006*"‘" + 0.006*"save" + 0.006*"medic" + 0.006*"econom"
# 2021-05-18 15:38:00,373 : INFO : topic diff=0.120405, rho=0.176269
# 2021-05-18 15:38:00,380 : INFO : PROGRESS: pass 24, dispatched chunk #5 = documents up to #12000/14369, outstanding queue size 3
# 2021-05-18 15:38:05,665 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:05,969 : INFO : topic #4 (0.050): 0.029*"#auspol" + 0.021*"morrison" + 0.015*"scott" + 0.015*"#polita" + 0.013*"scott_morrison" + 0.013*"climat" + 0.011*"pm" + 0.010*"need" + 0.009*"#auspol_#polita" + 0.008*"coal"
# 2021-05-18 15:38:05,972 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"-" + 0.009*"australian" + 0.009*"help" + 0.007*"bushfir" + 0.007*"coronaviru" + 0.007*"keep" + 0.006*"work"
# 2021-05-18 15:38:05,986 : INFO : topic #9 (0.050): 0.055*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"care" + 0.006*"liber" + 0.005*"minist"
# 2021-05-18 15:38:05,991 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"parliament" + 0.005*"govt" + 0.005*"australia" + 0.004*"need" + 0.004*"support"
# 2021-05-18 15:38:05,993 : INFO : topic #2 (0.050): 0.021*"great" + 0.014*"day" + 0.012*"thank" + 0.010*"today" + 0.008*"commun" + 0.008*"year" + 0.007*"celebr" + 0.005*"morn" + 0.005*"good" + 0.005*"team"
# 2021-05-18 15:38:05,996 : INFO : topic diff=0.091918, rho=0.176269
# 2021-05-18 15:38:06,020 : INFO : PROGRESS: pass 24, dispatched chunk #6 = documents up to #14000/14369, outstanding queue size 3
# 2021-05-18 15:38:13,963 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:14,332 : INFO : topic #8 (0.050): 0.017*"…" + 0.016*"vaccin" + 0.007*"australia" + 0.007*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:38:14,342 : INFO : topic #0 (0.050): 0.025*"servic" + 0.019*"day" + 0.014*"anzac" + 0.013*"honour" + 0.011*"rememb" + 0.010*"commemor" + 0.009*"war" + 0.009*"today" + 0.009*"memori" + 0.008*"forget"
# 2021-05-18 15:38:14,349 : INFO : topic #2 (0.050): 0.021*"great" + 0.014*"day" + 0.012*"thank" + 0.010*"today" + 0.008*"commun" + 0.008*"year" + 0.007*"celebr" + 0.005*"morn" + 0.005*"good" + 0.005*"…"
# 2021-05-18 15:38:14,354 : INFO : topic #3 (0.050): 0.019*"servic" + 0.012*"support" + 0.009*"australian" + 0.008*"provid" + 0.008*"ndi" + 0.007*"#ndi" + 0.007*"particip" + 0.006*"assist" + 0.006*"deliv" + 0.006*"year"
# 2021-05-18 15:38:14,362 : INFO : topic #12 (0.050): 0.025*"turnbul" + 0.017*"cut" + 0.014*"…" + 0.014*"labor" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.007*"malcolm" + 0.006*"great" + 0.006*"fund"
# 2021-05-18 15:38:14,368 : INFO : topic diff=0.114342, rho=0.176269
# 2021-05-18 15:38:14,374 : INFO : PROGRESS: pass 24, dispatched chunk #7 = documents up to #14369/14369, outstanding queue size 3
# 2021-05-18 15:38:22,109 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:22,257 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.015*"…" + 0.010*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"parliament" + 0.005*"australia" + 0.005*"govt" + 0.004*"peopl" + 0.004*"support"
# 2021-05-18 15:38:22,268 : INFO : topic #0 (0.050): 0.025*"servic" + 0.019*"day" + 0.014*"honour" + 0.013*"anzac" + 0.011*"rememb" + 0.009*"commemor" + 0.009*"war" + 0.009*"today" + 0.009*"memori" + 0.008*"serv"
# 2021-05-18 15:38:22,271 : INFO : topic #19 (0.050): 0.018*"…" + 0.011*"bushfir" + 0.010*"support" + 0.009*"health" + 0.009*"help" + 0.009*"australian" + 0.008*"-" + 0.008*"fire" + 0.006*"keep" + 0.006*"work"
# 2021-05-18 15:38:22,274 : INFO : topic #16 (0.050): 0.012*"home" + 0.008*"super" + 0.007*"australian" + 0.007*"use" + 0.007*"australia" + 0.007*"‘" + 0.006*"save" + 0.006*"econom" + 0.006*"medic" + 0.005*"🏼"
# 2021-05-18 15:38:22,278 : INFO : topic #3 (0.050): 0.022*"servic" + 0.012*"support" + 0.010*"#ndi" + 0.009*"australian" + 0.009*"ndi" + 0.008*"provid" + 0.008*"particip" + 0.007*"assist" + 0.006*"disast" + 0.006*"disabl"
# 2021-05-18 15:38:22,282 : INFO : topic diff=0.107832, rho=0.176269
# 2021-05-18 15:38:30,560 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:30,723 : INFO : topic #7 (0.050): 0.025*"…" + 0.014*"australia" + 0.013*"australian" + 0.010*"🇺" + 0.009*"🇦" + 0.009*"🇦_🇺" + 0.008*"today" + 0.008*"️" + 0.007*"job" + 0.006*"support"
# 2021-05-18 15:38:30,730 : INFO : topic #11 (0.050): 0.021*"region" + 0.021*"#tyfi" + 0.008*"year" + 0.008*"#youradf" + 0.008*"commun" + 0.008*"#lovegippsland" + 0.008*"birthday" + 0.007*"servic" + 0.007*"serv" + 0.007*"happi"
# 2021-05-18 15:38:30,736 : INFO : topic #17 (0.050): 0.013*"australia" + 0.012*"australian" + 0.011*"busi" + 0.010*"tax" + 0.010*"great" + 0.008*"small" + 0.007*"citizen" + 0.007*"small_busi" + 0.007*"day" + 0.006*"famili"
# 2021-05-18 15:38:30,749 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"-" + 0.009*"help" + 0.009*"australian" + 0.009*"coronaviru" + 0.009*"bushfir" + 0.007*"keep" + 0.006*"work"
# 2021-05-18 15:38:30,753 : INFO : topic #0 (0.050): 0.025*"servic" + 0.019*"day" + 0.014*"honour" + 0.013*"anzac" + 0.012*"rememb" + 0.010*"war" + 0.010*"commemor" + 0.009*"today" + 0.009*"serv" + 0.008*"memori"
# 2021-05-18 15:38:30,764 : INFO : topic diff=0.145588, rho=0.176269
# 2021-05-18 15:38:32,199 : INFO : merging changes from 369 documents into a model of 14369 documents
# 2021-05-18 15:38:32,319 : INFO : topic #12 (0.050): 0.019*"turnbul" + 0.018*"cut" + 0.015*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"great" + 0.006*"tax"
# 2021-05-18 15:38:32,322 : INFO : topic #6 (0.050): 0.014*"great" + 0.010*"today" + 0.007*"farmer" + 0.007*"new" + 0.006*"drought" + 0.005*"region" + 0.005*"minist" + 0.005*"meet" + 0.005*"discuss" + 0.005*"trade"
# 2021-05-18 15:38:32,331 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.017*"…" + 0.008*"australia" + 0.008*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:38:32,337 : INFO : topic #3 (0.050): 0.020*"servic" + 0.014*"support" + 0.010*"#ndi" + 0.010*"australian" + 0.009*"provid" + 0.009*"particip" + 0.008*"ndi" + 0.007*"assist" + 0.006*"•" + 0.006*"deliv"
# 2021-05-18 15:38:32,343 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.010*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.005*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:38:32,347 : INFO : topic diff=0.214121, rho=0.176269
# 2021-05-18 15:38:34,438 : INFO : -8.460 per-word bound, 352.2 perplexity estimate based on a held-out corpus of 369 documents with 270152 words
# 2021-05-18 15:38:34,445 : INFO : PROGRESS: pass 25, dispatched chunk #0 = documents up to #2000/14369, outstanding queue size 1
# 2021-05-18 15:38:34,517 : INFO : PROGRESS: pass 25, dispatched chunk #1 = documents up to #4000/14369, outstanding queue size 2
# 2021-05-18 15:38:34,609 : INFO : PROGRESS: pass 25, dispatched chunk #2 = documents up to #6000/14369, outstanding queue size 3
# 2021-05-18 15:38:36,880 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:37,078 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.014*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"care" + 0.007*"liber" + 0.006*"minist"
# 2021-05-18 15:38:37,082 : INFO : topic #16 (0.050): 0.012*"home" + 0.009*"super" + 0.008*"use" + 0.007*"australian" + 0.007*"covid" + 0.007*"australia" + 0.007*"‘" + 0.006*"save" + 0.006*"medic" + 0.006*"econom"
# 2021-05-18 15:38:37,093 : INFO : topic #15 (0.050): 0.013*"fund" + 0.012*"budget" + 0.012*"tax" + 0.012*"million" + 0.011*"plan" + 0.011*"govern" + 0.011*"new" + 0.010*"year" + 0.009*"announc" + 0.008*"invest"
# 2021-05-18 15:38:37,101 : INFO : topic #0 (0.050): 0.024*"servic" + 0.018*"day" + 0.013*"anzac" + 0.013*"honour" + 0.011*"rememb" + 0.009*"war" + 0.009*"commemor" + 0.009*"today" + 0.008*"forget" + 0.008*"serv"
# 2021-05-18 15:38:37,112 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.006*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:38:37,118 : INFO : topic diff=0.152437, rho=0.173593
# 2021-05-18 15:38:37,121 : INFO : PROGRESS: pass 25, dispatched chunk #3 = documents up to #8000/14369, outstanding queue size 3
# 2021-05-18 15:38:39,838 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:40,024 : INFO : topic #10 (0.050): 0.030*"…" + 0.009*"parliament" + 0.007*"time" + 0.006*"pm" + 0.006*"question" + 0.005*"➡" + 0.005*"ask" + 0.005*"one" + 0.005*"look" + 0.004*"minist"
# 2021-05-18 15:38:40,028 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"-" + 0.009*"australian" + 0.009*"help" + 0.008*"coronaviru" + 0.008*"bushfir" + 0.007*"keep" + 0.006*"covid_-"
# 2021-05-18 15:38:40,031 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.008*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:38:40,035 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.008*"local" + 0.007*"#auspol" + 0.006*"thank" + 0.006*"…" + 0.006*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:38:40,037 : INFO : topic #15 (0.050): 0.013*"fund" + 0.013*"budget" + 0.012*"tax" + 0.011*"million" + 0.011*"plan" + 0.011*"new" + 0.011*"govern" + 0.010*"year" + 0.009*"announc" + 0.008*"invest"
# 2021-05-18 15:38:40,043 : INFO : topic diff=0.126486, rho=0.173593
# 2021-05-18 15:38:40,046 : INFO : PROGRESS: pass 25, dispatched chunk #4 = documents up to #10000/14369, outstanding queue size 3
# 2021-05-18 15:38:43,906 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:44,130 : INFO : topic #15 (0.050): 0.013*"budget" + 0.013*"fund" + 0.012*"tax" + 0.011*"million" + 0.011*"new" + 0.011*"plan" + 0.011*"govern" + 0.010*"year" + 0.009*"announc" + 0.008*"invest"
# 2021-05-18 15:38:44,149 : INFO : topic #7 (0.050): 0.024*"…" + 0.014*"australia" + 0.012*"australian" + 0.010*"🇺" + 0.009*"🇦" + 0.009*"🇦_🇺" + 0.008*"today" + 0.007*"️" + 0.007*"job" + 0.007*"support"
# 2021-05-18 15:38:44,163 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"parliament" + 0.005*"australia" + 0.005*"govt" + 0.004*"support" + 0.004*"peopl"
# 2021-05-18 15:38:44,171 : INFO : topic #14 (0.050): 0.019*"morrison" + 0.012*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.007*"jobkeep" + 0.006*"care" + 0.006*"women" + 0.006*"need"
# 2021-05-18 15:38:44,177 : INFO : topic #2 (0.050): 0.021*"great" + 0.013*"day" + 0.012*"thank" + 0.010*"today" + 0.008*"year" + 0.008*"commun" + 0.007*"celebr" + 0.005*"good" + 0.005*"morn" + 0.005*"team"
# 2021-05-18 15:38:44,184 : INFO : topic diff=0.118193, rho=0.173593
# 2021-05-18 15:38:44,195 : INFO : PROGRESS: pass 25, dispatched chunk #5 = documents up to #12000/14369, outstanding queue size 3
# 2021-05-18 15:38:49,451 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:49,721 : INFO : topic #11 (0.050): 0.019*"region" + 0.019*"#tyfi" + 0.008*"#youradf" + 0.008*"birthday" + 0.008*"year" + 0.008*"servic" + 0.008*"happi" + 0.007*"commun" + 0.007*"serv" + 0.007*"help"
# 2021-05-18 15:38:49,729 : INFO : topic #17 (0.050): 0.012*"australia" + 0.011*"busi" + 0.011*"australian" + 0.011*"great" + 0.011*"tax" + 0.008*"small" + 0.007*"citizen" + 0.007*"small_busi" + 0.007*"aussi" + 0.007*"day"
# 2021-05-18 15:38:49,736 : INFO : topic #13 (0.050): 0.023*"…" + 0.011*"veteran" + 0.009*"women" + 0.009*"peopl" + 0.007*"today" + 0.006*"royal" + 0.006*"suicid" + 0.006*"#anzacday" + 0.006*"commiss" + 0.006*"royal_commiss"
# 2021-05-18 15:38:49,747 : INFO : topic #12 (0.050): 0.020*"turnbul" + 0.017*"cut" + 0.014*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"abbott" + 0.007*"today" + 0.006*"fund" + 0.006*"tafe"
# 2021-05-18 15:38:49,760 : INFO : topic #3 (0.050): 0.019*"servic" + 0.013*"support" + 0.009*"australian" + 0.008*"#ndi" + 0.008*"provid" + 0.008*"ndi" + 0.007*"particip" + 0.007*"assist" + 0.006*"deliv" + 0.006*"year"
# 2021-05-18 15:38:49,768 : INFO : topic diff=0.090383, rho=0.173593
# 2021-05-18 15:38:49,773 : INFO : PROGRESS: pass 25, dispatched chunk #6 = documents up to #14000/14369, outstanding queue size 3
# 2021-05-18 15:38:58,127 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:38:58,450 : INFO : topic #16 (0.050): 0.012*"home" + 0.008*"super" + 0.007*"use" + 0.007*"australian" + 0.007*"australia" + 0.006*"‘" + 0.006*"save" + 0.006*"covid" + 0.006*"medic" + 0.006*"econom"
# 2021-05-18 15:38:58,457 : INFO : topic #11 (0.050): 0.020*"region" + 0.016*"#tyfi" + 0.008*"year" + 0.008*"birthday" + 0.008*"servic" + 0.008*"#youradf" + 0.007*"happi" + 0.007*"commun" + 0.007*"work" + 0.007*"help"
# 2021-05-18 15:38:58,466 : INFO : topic #8 (0.050): 0.017*"…" + 0.016*"vaccin" + 0.008*"australia" + 0.007*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:38:58,477 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"health" + 0.010*"support" + 0.009*"-" + 0.009*"australian" + 0.009*"help" + 0.007*"bushfir" + 0.006*"keep" + 0.006*"work" + 0.006*"coronaviru"
# 2021-05-18 15:38:58,481 : INFO : topic #15 (0.050): 0.015*"tax" + 0.014*"budget" + 0.013*"fund" + 0.012*"million" + 0.011*"plan" + 0.011*"govern" + 0.011*"new" + 0.010*"year" + 0.010*"announc" + 0.008*"deliv"
# 2021-05-18 15:38:58,509 : INFO : topic diff=0.112320, rho=0.173593
# 2021-05-18 15:38:58,512 : INFO : PROGRESS: pass 25, dispatched chunk #7 = documents up to #14369/14369, outstanding queue size 3
# 2021-05-18 15:39:06,392 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:06,663 : INFO : topic #15 (0.050): 0.016*"tax" + 0.013*"fund" + 0.013*"budget" + 0.012*"million" + 0.012*"plan" + 0.011*"govern" + 0.011*"new" + 0.010*"year" + 0.010*"announc" + 0.009*"deliv"
# 2021-05-18 15:39:06,675 : INFO : topic #11 (0.050): 0.021*"region" + 0.016*"#tyfi" + 0.008*"year" + 0.008*"#lovegippsland" + 0.008*"commun" + 0.008*"servic" + 0.007*"birthday" + 0.007*"happi" + 0.007*"#youradf" + 0.007*"help"
# 2021-05-18 15:39:06,678 : INFO : topic #6 (0.050): 0.014*"great" + 0.010*"today" + 0.008*"farmer" + 0.007*"new" + 0.006*"drought" + 0.005*"region" + 0.005*"meet" + 0.005*"minist" + 0.005*"trade" + 0.005*"discuss"
# 2021-05-18 15:39:06,680 : INFO : topic #3 (0.050): 0.022*"servic" + 0.012*"support" + 0.010*"#ndi" + 0.009*"australian" + 0.009*"ndi" + 0.008*"provid" + 0.008*"particip" + 0.007*"assist" + 0.006*"disast" + 0.006*"disabl"
# 2021-05-18 15:39:06,684 : INFO : topic #17 (0.050): 0.013*"australia" + 0.012*"australian" + 0.012*"tax" + 0.011*"busi" + 0.010*"great" + 0.008*"small" + 0.007*"citizen" + 0.007*"small_busi" + 0.007*"famili" + 0.007*"day"
# 2021-05-18 15:39:06,687 : INFO : topic diff=0.106077, rho=0.173593
# 2021-05-18 15:39:14,754 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:14,933 : INFO : topic #13 (0.050): 0.023*"…" + 0.009*"peopl" + 0.009*"veteran" + 0.009*"women" + 0.007*"today" + 0.006*"nation" + 0.006*"royal" + 0.005*"commiss" + 0.005*"suicid" + 0.005*"australian"
# 2021-05-18 15:39:14,936 : INFO : topic #0 (0.050): 0.025*"servic" + 0.019*"day" + 0.014*"honour" + 0.013*"anzac" + 0.012*"rememb" + 0.011*"war" + 0.010*"commemor" + 0.009*"today" + 0.009*"serv" + 0.009*"memori"
# 2021-05-18 15:39:14,939 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.007*"scott" + 0.007*"liber" + 0.007*"care" + 0.007*"scott_morrison" + 0.005*"minist"
# 2021-05-18 15:39:14,942 : INFO : topic #16 (0.050): 0.014*"home" + 0.010*"super" + 0.007*"australian" + 0.007*"australia" + 0.007*"use" + 0.007*"covid" + 0.007*"save" + 0.006*"econom" + 0.006*"‘" + 0.006*"🏼"
# 2021-05-18 15:39:14,944 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"australia" + 0.005*"parliament" + 0.005*"govt" + 0.004*"peopl" + 0.004*"need"
# 2021-05-18 15:39:14,949 : INFO : topic diff=0.143114, rho=0.173593
# 2021-05-18 15:39:16,398 : INFO : merging changes from 369 documents into a model of 14369 documents
# 2021-05-18 15:39:16,516 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.017*"…" + 0.008*"australia" + 0.008*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:39:16,518 : INFO : topic #11 (0.050): 0.022*"#tyfi" + 0.019*"region" + 0.008*"year" + 0.008*"servic" + 0.008*"#youradf" + 0.008*"birthday" + 0.007*"serv" + 0.007*"happi" + 0.007*"commun" + 0.007*"help"
# 2021-05-18 15:39:16,521 : INFO : topic #16 (0.050): 0.013*"home" + 0.009*"super" + 0.008*"use" + 0.007*"australian" + 0.007*"covid" + 0.007*"australia" + 0.007*"‘" + 0.006*"save" + 0.006*"medic" + 0.006*"econom"
# 2021-05-18 15:39:16,529 : INFO : topic #10 (0.050): 0.031*"…" + 0.009*"parliament" + 0.007*"time" + 0.006*"pm" + 0.006*"➡" + 0.006*"question" + 0.005*"ask" + 0.005*"one" + 0.005*"minist" + 0.004*"look"
# 2021-05-18 15:39:16,539 : INFO : topic #7 (0.050): 0.025*"…" + 0.014*"australia" + 0.013*"australian" + 0.010*"🇺" + 0.009*"🇦" + 0.009*"🇦_🇺" + 0.009*"today" + 0.007*"️" + 0.007*"job" + 0.007*"support"
# 2021-05-18 15:39:16,550 : INFO : topic diff=0.211414, rho=0.173593
# 2021-05-18 15:39:18,648 : INFO : -8.460 per-word bound, 352.2 perplexity estimate based on a held-out corpus of 369 documents with 270152 words
# 2021-05-18 15:39:18,665 : INFO : PROGRESS: pass 26, dispatched chunk #0 = documents up to #2000/14369, outstanding queue size 1
# 2021-05-18 15:39:18,724 : INFO : PROGRESS: pass 26, dispatched chunk #1 = documents up to #4000/14369, outstanding queue size 2
# 2021-05-18 15:39:18,735 : INFO : PROGRESS: pass 26, dispatched chunk #2 = documents up to #6000/14369, outstanding queue size 3
# 2021-05-18 15:39:21,119 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:21,288 : INFO : topic #7 (0.050): 0.025*"…" + 0.014*"australia" + 0.013*"australian" + 0.010*"🇺" + 0.009*"🇦" + 0.009*"🇦_🇺" + 0.008*"today" + 0.007*"️" + 0.007*"job" + 0.007*"support"
# 2021-05-18 15:39:21,302 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"parliament" + 0.005*"govt" + 0.005*"australia" + 0.004*"peopl" + 0.004*"need"
# 2021-05-18 15:39:21,309 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.014*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"liber" + 0.007*"care" + 0.006*"minist"
# 2021-05-18 15:39:21,315 : INFO : topic #6 (0.050): 0.014*"great" + 0.010*"today" + 0.007*"farmer" + 0.007*"new" + 0.005*"drought" + 0.005*"region" + 0.005*"minist" + 0.005*"meet" + 0.005*"discuss" + 0.005*"trade"
# 2021-05-18 15:39:21,322 : INFO : topic #4 (0.050): 0.025*"#auspol" + 0.023*"morrison" + 0.017*"scott" + 0.015*"scott_morrison" + 0.014*"climat" + 0.011*"pm" + 0.010*"need" + 0.009*"#polita" + 0.008*"coal" + 0.007*"govern"
# 2021-05-18 15:39:21,329 : INFO : topic diff=0.149994, rho=0.171035
# 2021-05-18 15:39:21,334 : INFO : PROGRESS: pass 26, dispatched chunk #3 = documents up to #8000/14369, outstanding queue size 3
# 2021-05-18 15:39:24,055 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:24,274 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"thank" + 0.006*"…" + 0.006*"meet" + 0.005*"morn" + 0.005*"coast"
# 2021-05-18 15:39:24,290 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.014*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"care" + 0.007*"liber" + 0.006*"minist"
# 2021-05-18 15:39:24,306 : INFO : topic #5 (0.050): 0.016*"labor" + 0.015*"vote" + 0.012*"elect" + 0.009*"thank" + 0.009*"liber" + 0.008*"#auspol" + 0.007*"campaign" + 0.007*"get" + 0.006*"go" + 0.006*"#ausvot"
# 2021-05-18 15:39:24,318 : INFO : topic #14 (0.050): 0.020*"morrison" + 0.012*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.007*"jobkeep" + 0.006*"care" + 0.006*"women" + 0.006*"need"
# 2021-05-18 15:39:24,324 : INFO : topic #12 (0.050): 0.018*"cut" + 0.016*"turnbul" + 0.015*"labor" + 0.013*"…" + 0.012*"#auspol" + 0.008*"school" + 0.008*"abbott" + 0.007*"today" + 0.006*"fund" + 0.006*"great"
# 2021-05-18 15:39:24,330 : INFO : topic diff=0.124518, rho=0.171035
# 2021-05-18 15:39:24,335 : INFO : PROGRESS: pass 26, dispatched chunk #4 = documents up to #10000/14369, outstanding queue size 3
# 2021-05-18 15:39:28,501 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:28,832 : INFO : topic #3 (0.050): 0.020*"servic" + 0.013*"support" + 0.009*"#ndi" + 0.009*"australian" + 0.008*"provid" + 0.008*"particip" + 0.007*"ndi" + 0.007*"assist" + 0.006*"disast" + 0.006*"deliv"
# 2021-05-18 15:39:28,837 : INFO : topic #10 (0.050): 0.030*"…" + 0.009*"parliament" + 0.007*"time" + 0.006*"pm" + 0.006*"question" + 0.005*"➡" + 0.005*"ask" + 0.005*"one" + 0.005*"look" + 0.004*"minist"
# 2021-05-18 15:39:28,852 : INFO : topic #11 (0.050): 0.021*"#tyfi" + 0.019*"region" + 0.008*"year" + 0.008*"#youradf" + 0.008*"birthday" + 0.008*"servic" + 0.008*"happi" + 0.007*"serv" + 0.007*"commun" + 0.007*"help"
# 2021-05-18 15:39:28,863 : INFO : topic #6 (0.050): 0.014*"great" + 0.010*"today" + 0.006*"farmer" + 0.006*"new" + 0.005*"meet" + 0.005*"minist" + 0.005*"region" + 0.005*"discuss" + 0.005*"trade" + 0.004*"open"
# 2021-05-18 15:39:28,866 : INFO : topic #2 (0.050): 0.021*"great" + 0.013*"day" + 0.013*"thank" + 0.010*"today" + 0.009*"year" + 0.008*"commun" + 0.007*"celebr" + 0.005*"good" + 0.005*"morn" + 0.005*"team"
# 2021-05-18 15:39:28,892 : INFO : topic diff=0.116111, rho=0.171035
# 2021-05-18 15:39:28,895 : INFO : PROGRESS: pass 26, dispatched chunk #5 = documents up to #12000/14369, outstanding queue size 3
# 2021-05-18 15:39:33,489 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:34,220 : INFO : topic #12 (0.050): 0.020*"turnbul" + 0.018*"cut" + 0.015*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"abbott" + 0.007*"today" + 0.006*"fund" + 0.006*"tafe"
# 2021-05-18 15:39:34,227 : INFO : topic #11 (0.050): 0.019*"region" + 0.019*"#tyfi" + 0.008*"#youradf" + 0.008*"birthday" + 0.008*"year" + 0.008*"servic" + 0.008*"happi" + 0.007*"commun" + 0.007*"serv" + 0.007*"help"
# 2021-05-18 15:39:34,236 : INFO : topic #0 (0.050): 0.025*"servic" + 0.019*"day" + 0.016*"anzac" + 0.013*"honour" + 0.011*"rememb" + 0.010*"commemor" + 0.009*"war" + 0.009*"today" + 0.009*"forget" + 0.009*"memori"
# 2021-05-18 15:39:34,247 : INFO : topic #8 (0.050): 0.018*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.007*"labor" + 0.007*"govern" + 0.007*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:39:34,256 : INFO : topic #1 (0.050): 0.015*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.005*"govern" + 0.005*"parliament" + 0.005*"govt" + 0.005*"australia" + 0.004*"need" + 0.004*"support"
# 2021-05-18 15:39:34,263 : INFO : topic diff=0.088931, rho=0.171035
# 2021-05-18 15:39:34,278 : INFO : PROGRESS: pass 26, dispatched chunk #6 = documents up to #14000/14369, outstanding queue size 3
# 2021-05-18 15:39:42,502 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:42,833 : INFO : topic #8 (0.050): 0.017*"…" + 0.016*"vaccin" + 0.008*"australia" + 0.008*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:39:42,837 : INFO : topic #16 (0.050): 0.012*"home" + 0.008*"super" + 0.007*"use" + 0.007*"australian" + 0.007*"australia" + 0.006*"‘" + 0.006*"save" + 0.006*"covid" + 0.006*"medic" + 0.006*"econom"
# 2021-05-18 15:39:42,850 : INFO : topic #3 (0.050): 0.020*"servic" + 0.013*"support" + 0.009*"australian" + 0.008*"provid" + 0.008*"ndi" + 0.008*"#ndi" + 0.007*"particip" + 0.007*"assist" + 0.006*"deliv" + 0.006*"year"
# 2021-05-18 15:39:42,860 : INFO : topic #2 (0.050): 0.021*"great" + 0.014*"day" + 0.012*"thank" + 0.010*"today" + 0.009*"year" + 0.008*"commun" + 0.008*"celebr" + 0.005*"good" + 0.005*"morn" + 0.005*"team"
# 2021-05-18 15:39:42,865 : INFO : topic #6 (0.050): 0.014*"great" + 0.010*"today" + 0.007*"farmer" + 0.006*"new" + 0.006*"minist" + 0.006*"meet" + 0.005*"trade" + 0.005*"region" + 0.005*"discuss" + 0.004*"open"
# 2021-05-18 15:39:42,873 : INFO : topic diff=0.110408, rho=0.171035
# 2021-05-18 15:39:42,880 : INFO : PROGRESS: pass 26, dispatched chunk #7 = documents up to #14369/14369, outstanding queue size 3
# 2021-05-18 15:39:50,809 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:51,089 : INFO : topic #19 (0.050): 0.018*"…" + 0.011*"bushfir" + 0.010*"support" + 0.009*"health" + 0.009*"help" + 0.009*"australian" + 0.008*"-" + 0.008*"fire" + 0.006*"keep" + 0.006*"work"
# 2021-05-18 15:39:51,092 : INFO : topic #14 (0.050): 0.019*"morrison" + 0.014*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.006*"care" + 0.006*"women" + 0.006*"need" + 0.006*"year"
# 2021-05-18 15:39:51,095 : INFO : topic #11 (0.050): 0.021*"region" + 0.016*"#tyfi" + 0.008*"year" + 0.008*"#lovegippsland" + 0.008*"commun" + 0.008*"servic" + 0.007*"birthday" + 0.007*"happi" + 0.007*"#youradf" + 0.007*"help"
# 2021-05-18 15:39:51,098 : INFO : topic #0 (0.050): 0.026*"servic" + 0.019*"day" + 0.014*"honour" + 0.013*"anzac" + 0.012*"rememb" + 0.009*"war" + 0.009*"commemor" + 0.009*"today" + 0.009*"memori" + 0.008*"serv"
# 2021-05-18 15:39:51,101 : INFO : topic #3 (0.050): 0.022*"servic" + 0.013*"support" + 0.010*"#ndi" + 0.009*"ndi" + 0.009*"australian" + 0.008*"provid" + 0.008*"particip" + 0.007*"assist" + 0.006*"disast" + 0.006*"disabl"
# 2021-05-18 15:39:51,105 : INFO : topic diff=0.104389, rho=0.171035
# 2021-05-18 15:39:59,182 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:39:59,455 : INFO : topic #15 (0.050): 0.014*"tax" + 0.014*"fund" + 0.013*"budget" + 0.012*"million" + 0.012*"plan" + 0.011*"govern" + 0.011*"new" + 0.010*"year" + 0.010*"announc" + 0.009*"invest"
# 2021-05-18 15:39:59,463 : INFO : topic #4 (0.050): 0.025*"#auspol" + 0.021*"morrison" + 0.020*"climat" + 0.015*"scott" + 0.013*"scott_morrison" + 0.011*"#polita" + 0.011*"coal" + 0.010*"pm" + 0.010*"wage_subsidi" + 0.010*"need"
# 2021-05-18 15:39:59,469 : INFO : topic #10 (0.050): 0.031*"…" + 0.008*"parliament" + 0.008*"➡" + 0.007*"time" + 0.006*"pm" + 0.005*"question" + 0.005*"one" + 0.004*"ask" + 0.004*"look" + 0.004*"minist"
# 2021-05-18 15:39:59,473 : INFO : topic #12 (0.050): 0.020*"turnbul" + 0.018*"cut" + 0.016*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"tax" + 0.006*"great"
# 2021-05-18 15:39:59,481 : INFO : topic #8 (0.050): 0.016*"…" + 0.012*"vaccin" + 0.008*"australia" + 0.007*"labor" + 0.007*"govern" + 0.007*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:39:59,487 : INFO : topic diff=0.140829, rho=0.171035
# 2021-05-18 15:40:00,717 : INFO : merging changes from 369 documents into a model of 14369 documents
# 2021-05-18 15:40:00,840 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.009*"local" + 0.007*"#auspol" + 0.006*"…" + 0.006*"thank" + 0.006*"meet" + 0.005*"morn" + 0.005*"commun"
# 2021-05-18 15:40:00,842 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"-" + 0.009*"australian" + 0.009*"help" + 0.008*"coronaviru" + 0.008*"bushfir" + 0.007*"keep" + 0.006*"covid"
# 2021-05-18 15:40:00,851 : INFO : topic #14 (0.050): 0.020*"morrison" + 0.012*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.008*"jobkeep" + 0.006*"care" + 0.006*"women" + 0.006*"need"
# 2021-05-18 15:40:00,861 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.008*"labor" + 0.007*"govern" + 0.006*"job" + 0.006*"get" + 0.006*"australian" + 0.005*"nation" + 0.005*"need"
# 2021-05-18 15:40:00,866 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.015*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"liber" + 0.007*"care" + 0.006*"minist"
# 2021-05-18 15:40:00,870 : INFO : topic diff=0.208838, rho=0.171035
# 2021-05-18 15:40:02,944 : INFO : -8.460 per-word bound, 352.1 perplexity estimate based on a held-out corpus of 369 documents with 270152 words
# 2021-05-18 15:40:02,950 : INFO : PROGRESS: pass 27, dispatched chunk #0 = documents up to #2000/14369, outstanding queue size 1
# 2021-05-18 15:40:03,014 : INFO : PROGRESS: pass 27, dispatched chunk #1 = documents up to #4000/14369, outstanding queue size 2
# 2021-05-18 15:40:03,026 : INFO : PROGRESS: pass 27, dispatched chunk #2 = documents up to #6000/14369, outstanding queue size 3
# 2021-05-18 15:40:05,399 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:40:05,581 : INFO : topic #19 (0.050): 0.018*"…" + 0.010*"support" + 0.010*"health" + 0.009*"-" + 0.009*"australian" + 0.009*"help" + 0.008*"coronaviru" + 0.008*"bushfir" + 0.007*"keep" + 0.006*"covid"
# 2021-05-18 15:40:05,584 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.015*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"liber" + 0.007*"care" + 0.006*"minist"
# 2021-05-18 15:40:05,588 : INFO : topic #12 (0.050): 0.019*"turnbul" + 0.018*"cut" + 0.015*"labor" + 0.014*"…" + 0.013*"#auspol" + 0.008*"school" + 0.007*"today" + 0.006*"fund" + 0.006*"tax" + 0.006*"great"
# 2021-05-18 15:40:05,593 : INFO : topic #14 (0.050): 0.020*"morrison" + 0.012*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.008*"jobkeep" + 0.006*"care" + 0.006*"women" + 0.006*"need"
# 2021-05-18 15:40:05,603 : INFO : topic #5 (0.050): 0.017*"labor" + 0.015*"vote" + 0.012*"elect" + 0.009*"liber" + 0.008*"thank" + 0.008*"#auspol" + 0.007*"get" + 0.007*"campaign" + 0.006*"go" + 0.006*"parti"
# 2021-05-18 15:40:05,623 : INFO : topic diff=0.147671, rho=0.168587
# 2021-05-18 15:40:05,627 : INFO : PROGRESS: pass 27, dispatched chunk #3 = documents up to #8000/14369, outstanding queue size 3
# 2021-05-18 15:40:08,451 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:40:08,651 : INFO : topic #12 (0.050): 0.018*"cut" + 0.017*"turnbul" + 0.015*"labor" + 0.014*"…" + 0.012*"#auspol" + 0.008*"school" + 0.008*"abbott" + 0.007*"today" + 0.006*"fund" + 0.006*"great"
# 2021-05-18 15:40:08,655 : INFO : topic #1 (0.050): 0.014*"#auspol" + 0.014*"…" + 0.009*"labor" + 0.006*"today" + 0.006*"govern" + 0.005*"parliament" + 0.005*"govt" + 0.005*"australia" + 0.004*"peopl" + 0.004*"need"
# 2021-05-18 15:40:08,659 : INFO : topic #16 (0.050): 0.013*"home" + 0.009*"super" + 0.008*"use" + 0.007*"australian" + 0.007*"covid" + 0.007*"australia" + 0.007*"‘" + 0.006*"save" + 0.006*"econom" + 0.006*"medic"
# 2021-05-18 15:40:08,672 : INFO : topic #7 (0.050): 0.025*"…" + 0.014*"australia" + 0.013*"australian" + 0.010*"🇺" + 0.009*"🇦" + 0.009*"🇦_🇺" + 0.009*"today" + 0.007*"️" + 0.007*"job" + 0.006*"support"
# 2021-05-18 15:40:08,677 : INFO : topic #10 (0.050): 0.031*"…" + 0.009*"parliament" + 0.007*"time" + 0.007*"pm" + 0.006*"question" + 0.006*"➡" + 0.005*"ask" + 0.005*"one" + 0.005*"minist" + 0.004*"look"
# 2021-05-18 15:40:08,692 : INFO : topic diff=0.122647, rho=0.168587
# 2021-05-18 15:40:08,700 : INFO : PROGRESS: pass 27, dispatched chunk #4 = documents up to #10000/14369, outstanding queue size 3
# 2021-05-18 15:40:12,049 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 15:40:12,517 : INFO : topic #18 (0.050): 0.013*"great" + 0.011*"today" + 0.009*"new" + 0.008*"local" + 0.007*"#auspol" + 0.006*"thank" + 0.006*"…" + 0.006*"meet" + 0.005*"coast" + 0.005*"morn"
# 2021-05-18 15:40:12,528 : INFO : topic #9 (0.050): 0.056*"…" + 0.015*"govern" + 0.015*"#auspol" + 0.013*"morrison" + 0.008*"australian" + 0.008*"scott" + 0.007*"scott_morrison" + 0.007*"liber" + 0.007*"care" + 0.006*"minist"
# 2021-05-18 15:40:12,534 : INFO : topic #4 (0.050): 0.027*"#auspol" + 0.022*"morrison" + 0.016*"scott" + 0.014*"climat" + 0.014*"scott_morrison" + 0.012*"#polita" + 0.011*"pm" + 0.010*"need" + 0.008*"coal" + 0.007*"govern"
# 2021-05-18 15:40:12,546 : INFO : topic #14 (0.050): 0.020*"morrison" + 0.012*"👇" + 0.011*"…" + 0.010*"govern" + 0.010*"morrison_govern" + 0.008*"australian" + 0.007*"jobkeep" + 0.006*"care" + 0.006*"women" + 0.006*"need"
# 2021-05-18 15:40:12,552 : INFO : topic #5 (0.050): 0.016*"labor" + 0.015*"vote" + 0.012*"elect" + 0.009*"thank" + 0.009*"liber" + 0.008*"#auspol" + 0.007*"campaign" + 0.007*"get" + 0.006*"go" + 0.006*"parti"
# 2021-05-18 15:40:12,571 : INFO : topic diff=0.114109, rho=0.168587
# ...
# 2021-05-18 16:32:07,731 : INFO : topic #2 (0.050): 0.020*"great" + 0.014*"day" + 0.013*"thank" + 0.011*"year" + 0.010*"today" + 0.009*"commun" + 0.008*"celebr" + 0.006*"good" + 0.005*"well" + 0.005*"congratul"
# 2021-05-18 16:32:07,748 : INFO : topic #12 (0.050): 0.024*"turnbul" + 0.021*"…" + 0.019*"labor" + 0.018*"cut" + 0.017*"#auspol" + 0.008*"school" + 0.007*"today" + 0.007*"tax" + 0.006*"malcolm" + 0.006*"fund"
# 2021-05-18 16:32:07,758 : INFO : topic #18 (0.050): 0.016*"great" + 0.012*"today" + 0.010*"#auspol" + 0.009*"local" + 0.008*"new" + 0.007*"meet" + 0.007*"thank" + 0.006*"morn" + 0.006*"commun" + 0.006*"visit"
# 2021-05-18 16:32:07,770 : INFO : topic diff=0.058719, rho=0.097044
# 2021-05-18 16:32:07,774 : INFO : PROGRESS: pass 98, dispatched chunk #7 = documents up to #14369/14369, outstanding queue size 3
# 2021-05-18 16:32:15,187 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:15,438 : INFO : topic #8 (0.050): 0.016*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.008*"govern" + 0.007*"labor" + 0.007*"get" + 0.007*"australian" + 0.006*"nation" + 0.006*"need" + 0.006*"job"
# 2021-05-18 16:32:15,442 : INFO : topic #13 (0.050): 0.030*"…" + 0.011*"veteran" + 0.010*"women" + 0.009*"today" + 0.009*"peopl" + 0.009*"royal" + 0.008*"commiss" + 0.007*"royal_commiss" + 0.007*"famili" + 0.007*"commun"
# 2021-05-18 16:32:15,456 : INFO : topic #0 (0.050): 0.029*"servic" + 0.020*"day" + 0.015*"anzac" + 0.015*"honour" + 0.012*"rememb" + 0.011*"war" + 0.011*"commemor" + 0.009*"serv" + 0.009*"forget" + 0.009*"memori"
# 2021-05-18 16:32:15,465 : INFO : topic #9 (0.050): 0.062*"…" + 0.019*"#auspol" + 0.017*"govern" + 0.012*"morrison" + 0.010*"liber" + 0.009*"australian" + 0.007*"care" + 0.007*"scott" + 0.006*"minist" + 0.006*"scott_morrison"
# 2021-05-18 16:32:15,477 : INFO : topic #15 (0.050): 0.016*"tax" + 0.014*"fund" + 0.013*"million" + 0.013*"plan" + 0.013*"budget" + 0.013*"govern" + 0.012*"year" + 0.011*"new" + 0.011*"announc" + 0.011*"labor"
# 2021-05-18 16:32:15,494 : INFO : topic diff=0.059074, rho=0.097044
# 2021-05-18 16:32:22,906 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:23,116 : INFO : topic #18 (0.050): 0.016*"great" + 0.012*"today" + 0.010*"#auspol" + 0.009*"local" + 0.009*"new" + 0.007*"meet" + 0.007*"thank" + 0.006*"morn" + 0.006*"commun" + 0.006*"visit"
# 2021-05-18 16:32:23,121 : INFO : topic #10 (0.050): 0.036*"…" + 0.013*"parliament" + 0.011*"pm" + 0.009*"minist" + 0.007*"➡" + 0.007*"time" + 0.007*"prime" + 0.007*"prime_minist" + 0.006*"question" + 0.005*"ask"
# 2021-05-18 16:32:23,126 : INFO : topic #4 (0.050): 0.033*"climat" + 0.022*"#auspol" + 0.020*"morrison" + 0.014*"scott" + 0.012*"scott_morrison" + 0.012*"#polita" + 0.011*"coal" + 0.011*"climat_chang" + 0.009*"need" + 0.008*"wage_subsidi"
# 2021-05-18 16:32:23,131 : INFO : topic #7 (0.050): 0.029*"…" + 0.014*"australia" + 0.013*"australian" + 0.010*"🇺" + 0.010*"today" + 0.010*"🇦" + 0.009*"🇦_🇺" + 0.008*"️" + 0.007*"minist" + 0.007*"work"
# 2021-05-18 16:32:23,138 : INFO : topic #14 (0.050): 0.024*"morrison" + 0.015*"👇" + 0.012*"morrison_govern" + 0.010*"govern" + 0.010*"…" + 0.008*"jobkeep" + 0.008*"worker" + 0.008*"women" + 0.007*"care" + 0.007*"scott_morrison"
# 2021-05-18 16:32:23,155 : INFO : topic diff=0.076533, rho=0.097044
# 2021-05-18 16:32:24,563 : INFO : merging changes from 369 documents into a model of 14369 documents
# 2021-05-18 16:32:24,696 : INFO : topic #19 (0.050): 0.018*"…" + 0.011*"health" + 0.011*"support" + 0.010*"-" + 0.010*"help" + 0.010*"australian" + 0.008*"bushfir" + 0.008*"coronaviru" + 0.007*"covid" + 0.007*"keep"
# 2021-05-18 16:32:24,699 : INFO : topic #15 (0.050): 0.014*"tax" + 0.014*"fund" + 0.013*"million" + 0.013*"plan" + 0.013*"budget" + 0.013*"govern" + 0.011*"year" + 0.011*"new" + 0.011*"announc" + 0.009*"labor"
# 2021-05-18 16:32:24,702 : INFO : topic #0 (0.050): 0.028*"servic" + 0.020*"day" + 0.015*"anzac" + 0.014*"honour" + 0.012*"rememb" + 0.011*"war" + 0.010*"commemor" + 0.010*"serv" + 0.010*"forget" + 0.009*"today"
# 2021-05-18 16:32:24,705 : INFO : topic #3 (0.050): 0.023*"servic" + 0.016*"support" + 0.011*"#ndi" + 0.010*"provid" + 0.009*"particip" + 0.008*"ndi" + 0.008*"assist" + 0.007*"nsw" + 0.007*"disast" + 0.007*"inform"
# 2021-05-18 16:32:24,708 : INFO : topic #6 (0.050): 0.011*"great" + 0.009*"farmer" + 0.009*"today" + 0.007*"region" + 0.007*"drought" + 0.006*"new" + 0.006*"minist" + 0.005*"trade" + 0.005*"water" + 0.005*"week"
# 2021-05-18 16:32:24,712 : INFO : topic diff=0.126632, rho=0.097044
# 2021-05-18 16:32:26,782 : INFO : -8.463 per-word bound, 352.9 perplexity estimate based on a held-out corpus of 369 documents with 270152 words
# 2021-05-18 16:32:26,788 : INFO : PROGRESS: pass 99, dispatched chunk #0 = documents up to #2000/14369, outstanding queue size 1
# 2021-05-18 16:32:26,859 : INFO : PROGRESS: pass 99, dispatched chunk #1 = documents up to #4000/14369, outstanding queue size 2
# 2021-05-18 16:32:26,862 : INFO : PROGRESS: pass 99, dispatched chunk #2 = documents up to #6000/14369, outstanding queue size 3
# 2021-05-18 16:32:29,074 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:29,267 : INFO : topic #12 (0.050): 0.020*"…" + 0.020*"turnbul" + 0.020*"labor" + 0.019*"cut" + 0.017*"#auspol" + 0.008*"school" + 0.007*"tax" + 0.007*"today" + 0.006*"fund" + 0.006*"abbott"
# 2021-05-18 16:32:29,271 : INFO : topic #13 (0.050): 0.029*"…" + 0.012*"veteran" + 0.009*"women" + 0.009*"today" + 0.009*"peopl" + 0.009*"royal" + 0.008*"commiss" + 0.007*"royal_commiss" + 0.007*"suicid" + 0.007*"famili"
# 2021-05-18 16:32:29,275 : INFO : topic #10 (0.050): 0.035*"…" + 0.013*"parliament" + 0.011*"pm" + 0.009*"minist" + 0.007*"time" + 0.007*"prime" + 0.006*"prime_minist" + 0.006*"question" + 0.006*"➡" + 0.006*"ask"
# 2021-05-18 16:32:29,279 : INFO : topic #8 (0.050): 0.020*"vaccin" + 0.016*"…" + 0.008*"australia" + 0.008*"govern" + 0.007*"labor" + 0.007*"get" + 0.007*"australian" + 0.006*"job" + 0.006*"need" + 0.006*"nation"
# 2021-05-18 16:32:29,283 : INFO : topic #1 (0.050): 0.012*"#auspol" + 0.010*"…" + 0.005*"labor" + 0.005*"peopl" + 0.005*"govern" + 0.005*"today" + 0.005*"parliament" + 0.005*"need" + 0.005*"australia" + 0.005*"govt"
# 2021-05-18 16:32:29,287 : INFO : topic diff=0.081742, rho=0.096590
# 2021-05-18 16:32:29,290 : INFO : PROGRESS: pass 99, dispatched chunk #3 = documents up to #8000/14369, outstanding queue size 3
# 2021-05-18 16:32:32,047 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:32,238 : INFO : topic #3 (0.050): 0.022*"servic" + 0.016*"support" + 0.011*"#ndi" + 0.010*"provid" + 0.009*"particip" + 0.008*"ndi" + 0.008*"assist" + 0.007*"nsw" + 0.007*"disast" + 0.007*"inform"
# 2021-05-18 16:32:32,241 : INFO : topic #9 (0.050): 0.061*"…" + 0.019*"#auspol" + 0.017*"govern" + 0.012*"morrison" + 0.010*"liber" + 0.009*"australian" + 0.007*"care" + 0.007*"scott" + 0.006*"scott_morrison" + 0.006*"minist"
# 2021-05-18 16:32:32,252 : INFO : topic #14 (0.050): 0.024*"morrison" + 0.013*"👇" + 0.011*"morrison_govern" + 0.010*"govern" + 0.010*"…" + 0.008*"women" + 0.008*"jobkeep" + 0.007*"worker" + 0.007*"scott_morrison" + 0.007*"care"
# 2021-05-18 16:32:32,268 : INFO : topic #10 (0.050): 0.035*"…" + 0.013*"parliament" + 0.011*"pm" + 0.009*"minist" + 0.007*"time" + 0.007*"prime" + 0.007*"question" + 0.006*"prime_minist" + 0.006*"➡" + 0.006*"ask"
# 2021-05-18 16:32:32,276 : INFO : topic #5 (0.050): 0.022*"labor" + 0.017*"vote" + 0.014*"elect" + 0.010*"liber" + 0.009*"thank" + 0.008*"campaign" + 0.008*"#auspol" + 0.007*"#ausvot" + 0.007*"parti" + 0.007*"get"
# 2021-05-18 16:32:32,283 : INFO : topic diff=0.068969, rho=0.096590
# 2021-05-18 16:32:32,286 : INFO : PROGRESS: pass 99, dispatched chunk #4 = documents up to #10000/14369, outstanding queue size 3
# 2021-05-18 16:32:35,819 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:36,015 : INFO : topic #1 (0.050): 0.012*"#auspol" + 0.010*"…" + 0.005*"labor" + 0.005*"peopl" + 0.005*"govern" + 0.005*"today" + 0.005*"parliament" + 0.005*"need" + 0.005*"australia" + 0.005*"govt"
# 2021-05-18 16:32:36,029 : INFO : topic #14 (0.050): 0.024*"morrison" + 0.013*"👇" + 0.011*"morrison_govern" + 0.010*"govern" + 0.010*"…" + 0.008*"women" + 0.008*"jobkeep" + 0.007*"worker" + 0.007*"scott_morrison" + 0.007*"care"
# 2021-05-18 16:32:36,034 : INFO : topic #15 (0.050): 0.014*"tax" + 0.014*"fund" + 0.014*"budget" + 0.013*"plan" + 0.013*"million" + 0.013*"govern" + 0.011*"year" + 0.011*"new" + 0.011*"announc" + 0.009*"labor"
# 2021-05-18 16:32:36,039 : INFO : topic #10 (0.050): 0.035*"…" + 0.013*"parliament" + 0.011*"pm" + 0.009*"minist" + 0.007*"time" + 0.007*"prime" + 0.007*"question" + 0.007*"prime_minist" + 0.006*"➡" + 0.006*"ask"
# 2021-05-18 16:32:36,044 : INFO : topic #5 (0.050): 0.022*"labor" + 0.017*"vote" + 0.014*"elect" + 0.010*"liber" + 0.009*"thank" + 0.008*"campaign" + 0.008*"#auspol" + 0.007*"#ausvot" + 0.007*"parti" + 0.007*"get"
# 2021-05-18 16:32:36,054 : INFO : topic diff=0.061363, rho=0.096590
# 2021-05-18 16:32:36,056 : INFO : PROGRESS: pass 99, dispatched chunk #5 = documents up to #12000/14369, outstanding queue size 3
# 2021-05-18 16:32:40,715 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:41,415 : INFO : topic #0 (0.050): 0.028*"servic" + 0.020*"day" + 0.016*"anzac" + 0.015*"honour" + 0.012*"rememb" + 0.011*"commemor" + 0.011*"war" + 0.010*"forget" + 0.009*"memori" + 0.009*"serv"
# 2021-05-18 16:32:41,418 : INFO : topic #12 (0.050): 0.021*"turnbul" + 0.020*"…" + 0.019*"labor" + 0.019*"cut" + 0.017*"#auspol" + 0.008*"school" + 0.007*"abbott" + 0.007*"today" + 0.007*"fund" + 0.007*"tax"
# 2021-05-18 16:32:41,429 : INFO : topic #2 (0.050): 0.020*"great" + 0.014*"day" + 0.013*"thank" + 0.011*"year" + 0.010*"today" + 0.009*"commun" + 0.008*"celebr" + 0.006*"good" + 0.005*"well" + 0.005*"new"
# 2021-05-18 16:32:41,435 : INFO : topic #7 (0.050): 0.028*"…" + 0.014*"australia" + 0.013*"australian" + 0.011*"🇺" + 0.010*"🇦" + 0.010*"today" + 0.010*"🇦_🇺" + 0.007*"minist" + 0.007*"️" + 0.007*"work"
# 2021-05-18 16:32:41,444 : INFO : topic #3 (0.050): 0.022*"servic" + 0.016*"support" + 0.010*"#ndi" + 0.009*"provid" + 0.009*"particip" + 0.008*"ndi" + 0.008*"assist" + 0.007*"nsw" + 0.007*"disast" + 0.006*"continu"
# 2021-05-18 16:32:41,453 : INFO : topic diff=0.048731, rho=0.096590
# 2021-05-18 16:32:41,461 : INFO : PROGRESS: pass 99, dispatched chunk #6 = documents up to #14000/14369, outstanding queue size 3
# 2021-05-18 16:32:49,314 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:49,569 : INFO : topic #3 (0.050): 0.022*"servic" + 0.016*"support" + 0.010*"#ndi" + 0.009*"provid" + 0.009*"particip" + 0.008*"ndi" + 0.008*"assist" + 0.007*"nsw" + 0.007*"disast" + 0.006*"continu"
# 2021-05-18 16:32:49,572 : INFO : topic #16 (0.050): 0.015*"home" + 0.009*"super" + 0.008*"use" + 0.007*"‘" + 0.007*"covid" + 0.007*"save" + 0.007*"australia" + 0.007*"econom" + 0.006*"first" + 0.006*"medic"
# 2021-05-18 16:32:49,576 : INFO : topic #11 (0.050): 0.020*"region" + 0.019*"#tyfi" + 0.008*"year" + 0.008*"#youradf" + 0.008*"servic" + 0.008*"birthday" + 0.007*"happi" + 0.007*"commun" + 0.007*"serv" + 0.007*"work"
# 2021-05-18 16:32:49,579 : INFO : topic #0 (0.050): 0.028*"servic" + 0.020*"day" + 0.016*"anzac" + 0.015*"honour" + 0.012*"rememb" + 0.011*"commemor" + 0.011*"war" + 0.010*"forget" + 0.009*"memori" + 0.009*"serv"
# 2021-05-18 16:32:49,581 : INFO : topic #10 (0.050): 0.036*"…" + 0.013*"parliament" + 0.011*"pm" + 0.009*"minist" + 0.007*"➡" + 0.007*"time" + 0.007*"prime" + 0.007*"prime_minist" + 0.006*"question" + 0.005*"ask"
# 2021-05-18 16:32:49,586 : INFO : topic diff=0.058415, rho=0.096590
# 2021-05-18 16:32:49,588 : INFO : PROGRESS: pass 99, dispatched chunk #7 = documents up to #14369/14369, outstanding queue size 3
# 2021-05-18 16:32:57,123 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:32:57,436 : INFO : topic #10 (0.050): 0.036*"…" + 0.013*"parliament" + 0.011*"pm" + 0.009*"minist" + 0.008*"➡" + 0.007*"time" + 0.007*"prime" + 0.007*"prime_minist" + 0.006*"question" + 0.005*"ask"
# 2021-05-18 16:32:57,443 : INFO : topic #9 (0.050): 0.062*"…" + 0.019*"#auspol" + 0.017*"govern" + 0.012*"morrison" + 0.010*"liber" + 0.009*"australian" + 0.007*"care" + 0.007*"scott" + 0.006*"minist" + 0.006*"scott_morrison"
# 2021-05-18 16:32:57,449 : INFO : topic #11 (0.050): 0.020*"region" + 0.018*"#tyfi" + 0.008*"year" + 0.008*"servic" + 0.008*"#youradf" + 0.007*"commun" + 0.007*"birthday" + 0.007*"work" + 0.007*"serv" + 0.007*"#lovegippsland"
# 2021-05-18 16:32:57,456 : INFO : topic #7 (0.050): 0.029*"…" + 0.014*"australia" + 0.013*"australian" + 0.011*"🇺" + 0.010*"🇦" + 0.010*"today" + 0.009*"🇦_🇺" + 0.008*"️" + 0.008*"minist" + 0.007*"work"
# 2021-05-18 16:32:57,463 : INFO : topic #6 (0.050): 0.011*"great" + 0.010*"farmer" + 0.009*"today" + 0.007*"region" + 0.007*"drought" + 0.006*"minist" + 0.006*"new" + 0.005*"trade" + 0.005*"water" + 0.005*"week"
# 2021-05-18 16:32:57,480 : INFO : topic diff=0.058808, rho=0.096590
# 2021-05-18 16:33:05,430 : INFO : merging changes from 2000 documents into a model of 14369 documents
# 2021-05-18 16:33:05,616 : INFO : topic #14 (0.050): 0.024*"morrison" + 0.015*"👇" + 0.012*"morrison_govern" + 0.010*"govern" + 0.010*"…" + 0.008*"jobkeep" + 0.008*"worker" + 0.008*"women" + 0.007*"care" + 0.007*"scott_morrison"
# 2021-05-18 16:33:05,623 : INFO : topic #4 (0.050): 0.033*"climat" + 0.022*"#auspol" + 0.020*"morrison" + 0.014*"scott" + 0.012*"scott_morrison" + 0.012*"#polita" + 0.011*"coal" + 0.011*"climat_chang" + 0.009*"need" + 0.008*"wage_subsidi"
# 2021-05-18 16:33:05,627 : INFO : topic #9 (0.050): 0.062*"…" + 0.019*"#auspol" + 0.017*"govern" + 0.012*"morrison" + 0.010*"liber" + 0.009*"australian" + 0.007*"care" + 0.007*"scott" + 0.006*"minist" + 0.006*"scott_morrison"
# 2021-05-18 16:33:05,631 : INFO : topic #13 (0.050): 0.029*"…" + 0.011*"veteran" + 0.009*"women" + 0.009*"today" + 0.009*"peopl" + 0.008*"royal" + 0.008*"commiss" + 0.007*"famili" + 0.007*"royal_commiss" + 0.007*"commun"
# 2021-05-18 16:33:05,636 : INFO : topic #5 (0.050): 0.023*"labor" + 0.017*"vote" + 0.015*"elect" + 0.011*"liber" + 0.009*"campaign" + 0.008*"thank" + 0.008*"#ausvot" + 0.008*"#auspol" + 0.007*"parti" + 0.007*"go"
# 2021-05-18 16:33:05,642 : INFO : topic diff=0.076152, rho=0.096590
# 2021-05-18 16:33:07,136 : INFO : merging changes from 369 documents into a model of 14369 documents
# 2021-05-18 16:33:07,271 : INFO : topic #13 (0.050): 0.030*"…" + 0.012*"veteran" + 0.009*"women" + 0.009*"today" + 0.009*"peopl" + 0.009*"royal" + 0.008*"commiss" + 0.008*"royal_commiss" + 0.007*"suicid" + 0.007*"famili"
# 2021-05-18 16:33:07,274 : INFO : topic #2 (0.050): 0.020*"great" + 0.014*"day" + 0.013*"thank" + 0.012*"year" + 0.010*"today" + 0.009*"commun" + 0.008*"celebr" + 0.006*"good" + 0.005*"well" + 0.005*"new"
# 2021-05-18 16:33:07,282 : INFO : topic #0 (0.050): 0.028*"servic" + 0.020*"day" + 0.015*"anzac" + 0.014*"honour" + 0.012*"rememb" + 0.011*"war" + 0.010*"commemor" + 0.010*"serv" + 0.010*"forget" + 0.009*"today"
# 2021-05-18 16:33:07,287 : INFO : topic #4 (0.050): 0.028*"climat" + 0.022*"#auspol" + 0.021*"morrison" + 0.016*"scott" + 0.014*"scott_morrison" + 0.010*"#polita" + 0.010*"coal" + 0.009*"climat_chang" + 0.009*"need" + 0.007*"pm"
# 2021-05-18 16:33:07,293 : INFO : topic #6 (0.050): 0.011*"great" + 0.009*"farmer" + 0.009*"today" + 0.007*"region" + 0.007*"drought" + 0.006*"new" + 0.006*"minist" + 0.005*"trade" + 0.005*"water" + 0.005*"week"
# 2021-05-18 16:33:07,297 : INFO : topic diff=0.126085, rho=0.096590
# 2021-05-18 16:33:09,444 : INFO : -8.463 per-word bound, 352.9 perplexity estimate based on a held-out corpus of 369 documents with 270152 words

# %%
#Finding the 10 most predictive tokens for each topic

#Using regex to filter the words from the weights 
words = [re.findall(r'"([^"]*)"',t[1]) for t in lda_model.print_topics(20,10)]

# Printing the topics in a nice format
for id, t in enumerate(words): 
    print(f"------ Topic {id} ------")
    print(' '.join(t), end="\n\n")
# Out:
# ------ Topic 0 ------
# servic day anzac honour rememb war commemor serv forget today
#
# ------ Topic 1 ------
# #auspol … labor peopl govern today parliament need australia govt
#
# ------ Topic 2 ------
# great day thank year today commun celebr good well new
#
# ------ Topic 3 ------
# servic support #ndi provid particip ndi assist nsw disast inform
#
# ------ Topic 4 ------
# climat #auspol morrison scott scott_morrison #polita coal climat_chang need pm
#
# ------ Topic 5 ------
# labor vote elect liber campaign thank #auspol parti #ausvot get
#
# ------ Topic 6 ------
# great farmer today region drought new minist trade water week
#
# ------ Topic 7 ------
# … australia australian 🇺 today 🇦 🇦_🇺 ️ minist work
#
# ------ Topic 8 ------
# vaccin … australia govern labor get australian job need nation
#
# ------ Topic 9 ------
# … #auspol govern morrison liber australian care scott scott_morrison minist
#
# ------ Topic 10 ------
# … parliament pm minist time prime prime_minist question ➡ ask
#
# ------ Topic 11 ------
# #tyfi region year servic #youradf serv birthday commun happi work
#
# ------ Topic 12 ------
# … turnbul labor cut #auspol school tax today fund educ
#
# ------ Topic 13 ------
# … veteran women today peopl royal commiss royal_commiss suicid famili
#
# ------ Topic 14 ------
# morrison 👇 morrison_govern govern … women jobkeep worker scott_morrison care
#
# ------ Topic 15 ------
# tax fund million plan budget govern year new announc labor
#
# ------ Topic 16 ------
# home super use covid ‘ save econom australia first medic
#
# ------ Topic 17 ------
# australian australia busi great tax famili citizen day small aussi
#
# ------ Topic 18 ------
# great today #auspol local new meet thank morn commun visit
#
# ------ Topic 19 ------
# … health support - help australian bushfir coronaviru covid keep

# %%
#Creating a dataframe with tokens as columns and topics as rows 
beta_df = pd.DataFrame(lda_model.get_topics(), columns = list(id2word.token2id.keys()))

# %%
#Picking 20 topics to visualize
topics = list(range(0, 20))

fig, axes = plt.subplots(ncols=4, nrows=5, figsize = (16,30)) #Setting 20 subplots and determining figure size
fig.tight_layout(pad=8.0) #This ensure space between the subplots so the text can more easily be read
    
for ax, topic in zip(axes.flatten(), topics): #Iterates through the axes and the topics
    
    #Creates 20 barplots with x as the beta values and y as the words
    sns.barplot(ax = ax, 
                x = beta_df.iloc[topic].nlargest(10).values, 
                y = beta_df.iloc[topic].nlargest(10).index, 
                orient = 'h')
    
    ax.set(title='Topic {}'.format(topic), xlabel='beta')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 127482 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 127462 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 128071 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 127482 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 127462 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 128071 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Insert the corpus of documents in bag of word format and get a list of (topic, probability) per document. 
document_topics = list(lda_model.get_document_topics(corpus)) 

#Creating a list of names for all 20 topics
topics = ['topic_{}'.format(t) for t in range(0,20)]

#Creating a dataframe of gamma probabilities 
gamma_probs = pd.DataFrame(np.zeros((len(document_topics),20)), columns = topics)

for i, doc in enumerate(document_topics): 
    for pair in doc: 
        gamma_probs.loc[i,'topic_{}'.format(pair[0])] = pair[1]

# %%
#Merging with the original dataframe 
gamma_df = pd.concat((tweets_agg,gamma_probs), axis = 1)

# %%
#Using regex to find all words and filter them from the weights
words = [re.findall(r'"([^"]*)"',t[1]) for t in lda_model.print_topics(20,10)]

# Printing the topics in a nice format
for id, t in enumerate(words): 
    print(f"------ Topic {id} ------")
    print(' '.join(t), end="\n\n")
# Out:
# ------ Topic 0 ------
# servic day anzac honour rememb war commemor serv forget today
#
# ------ Topic 1 ------
# #auspol … labor peopl govern today parliament need australia govt
#
# ------ Topic 2 ------
# great day thank year today commun celebr good well new
#
# ------ Topic 3 ------
# servic support #ndi provid particip ndi assist nsw disast inform
#
# ------ Topic 4 ------
# climat #auspol morrison scott scott_morrison #polita coal climat_chang need pm
#
# ------ Topic 5 ------
# labor vote elect liber campaign thank #auspol parti #ausvot get
#
# ------ Topic 6 ------
# great farmer today region drought new minist trade water week
#
# ------ Topic 7 ------
# … australia australian 🇺 today 🇦 🇦_🇺 ️ minist work
#
# ------ Topic 8 ------
# vaccin … australia govern labor get australian job need nation
#
# ------ Topic 9 ------
# … #auspol govern morrison liber australian care scott scott_morrison minist
#
# ------ Topic 10 ------
# … parliament pm minist time prime prime_minist question ➡ ask
#
# ------ Topic 11 ------
# #tyfi region year servic #youradf serv birthday commun happi work
#
# ------ Topic 12 ------
# … turnbul labor cut #auspol school tax today fund educ
#
# ------ Topic 13 ------
# … veteran women today peopl royal commiss royal_commiss suicid famili
#
# ------ Topic 14 ------
# morrison 👇 morrison_govern govern … women jobkeep worker scott_morrison care
#
# ------ Topic 15 ------
# tax fund million plan budget govern year new announc labor
#
# ------ Topic 16 ------
# home super use covid ‘ save econom australia first medic
#
# ------ Topic 17 ------
# australian australia busi great tax famili citizen day small aussi
#
# ------ Topic 18 ------
# great today #auspol local new meet thank morn commun visit
#
# ------ Topic 19 ------
# … health support - help australian bushfir coronaviru covid keep

# %%
# Date object
gamma_df["created_at"] = pd.to_datetime(gamma_df["created_at"])

# %%
#Setting a theme
#sns.set_theme(style="darkgrid")

#Plotting a figure and setting figure size
#plt.figure(figsize = (14,8))

#Choosing colors

#Plotting the covid topic for the full dataset
#sns.lineplot(x = 'date', y = 'topic_3', hue = 'p.party', data = gamma_df)

#plt.title('Topic of support over time (Topic 3)', fontsize = 16)
#plt.ylabel('Topic prevalence')
#plt.xlabel('created_at')

#plt.show()
