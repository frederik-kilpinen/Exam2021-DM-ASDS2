# %%
#Necessary imports
import pandas as pd
import numpy as np
from tqdm import tqdm
import tweepy
from datetime import date
import pickle 
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Subset data

# %%
mp_df = pd.read_csv("data/full_member_info.csv")
mp_df.shape
# Out:
# (15918, 37)

# %%
tweets = pd.read_csv("data/mp_tweets", index_col=0, low_memory=False)
#Original shape of the data
print(tweets.shape)
tweets.head()
# Out:
# (335975, 12)
#    screen_name      user_id      tweet_id           created_at  \
# 0  AlanTudgeMP  185932331.0  1.389486e+18  2021-05-04 07:42:40
# 1  AlanTudgeMP  185932331.0  1.389434e+18  2021-05-04 04:18:43
# 2  AlanTudgeMP  185932331.0  1.389430e+18  2021-05-04 04:01:51
# 3  AlanTudgeMP  185932331.0  1.389372e+18  2021-05-04 00:11:26
# 4  AlanTudgeMP  185932331.0  1.389002e+18  2021-05-02 23:39:42
#
#                                            full_text favorite_count  \
# 0  Research commercialisation in action. @QUT wor...             25
# 1  Hearing first hand how our extra $1.7b boost t...              7
# 2  RT @CISOZ: [NEW EDUCATION EVENT]\nTuesday 18 M...              0
# 3  Great to meet the kids, parents and teachers a...              5
# 4  RT @pmc_gov_au: Media Release @JoshFrydenberg ...              0
#
#    retweet_count in_reply_to_screen_name hashtags  \
# 0            5.0                     NaN       []
# 1            0.0                     NaN       []
# 2            5.0                     NaN       []
# 3            1.0                     NaN       []
# 4            4.0                     NaN       []
#
#                                        user_mentions  \
# 0                          ['QUT', 'TrevorEvansBne']
# 1                    ['GoodStartel', 'BertVanManen']
# 2                           ['CISOZ', 'AlanTudgeMP']
# 3                        ['Kingscc', 'BertVanManen']
# 4  ['pmc_gov_au', 'JoshFrydenberg', 'MarisePayne'...
#
#                                                  url  image_url
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3  https://ministers.dese.gov.au/tudge/new-facili...        NaN
# 4                                                NaN        NaN

# %%
class DataProcessing:

    def clean_tweet_data(self, tweet_df):

        #Rename user id column for merging with members_info data
        tweet_df = tweet_df.rename(columns = {"user_id":"m.uid"})

        #Drop 6 tweets that are corrupt. Because of it only being 6 tweets we drop them instead of re-running the collection from the API
        remove_idx = [175522, 190414, 211953, 212012, 212013, 212298 ]
        tweet_df = tweet_df.drop(tweet_df.index[remove_idx])

        #Make data into date-time object, remove h-m-s from dt
        tweet_df["created_at"] = pd.to_datetime(tweet_df["created_at"]).dt.date
        
        tweet_df["m.uid"] = tweet_df["m.uid"].astype(int)
        
        return tweet_df
    
    def clean_mp_data(self, mp_df):
        
        mp_df = mp_df[['p.country', 'm.name', 'p.party', 'm.uid', 'lp.official_legislative_period']]
        mp_df = mp_df.loc[mp_df["p.country"]=="Australia"]
        
        #TODO: Fix doctor
        remove = r"(^Hon\s{1}|^Mr\s{1}|^Ms\s{1}|^Mrs\s{1}|\s{1}MP|\s{1}AM|\s{1}OAM|\s{1}AO|\s{1}QC|^\D\r\s{1})"
        mp_df["m.name"] = mp_df["m.name"].str.replace(remove, "")
        
        mp_df = mp_df.loc[mp_df["m.uid"] != "\\N"]
        mp_df["m.uid"] = mp_df["m.uid"].astype(int)
        
        return mp_df
    
    def merge_final_df(self, tweet_df, mp_df):
        
        
        tweet_df = self.clean_tweet_data(tweet_df)
        mp_df = self.clean_mp_data(mp_df)
        
        #Merge to final df
        final_df = tweet_df.merge(mp_df, on = "m.uid", how = "left")
        
        #final_df = final_df.loc[((final_df["lp.official_legislative_period"] == "45") & (final_df["created_at"] < "2019-07-01"))|
        #                        ((final_df["lp.official_legislative_period"] == "46") & (final_df["created_at"] > "2019-07-01"))]
        
        return final_df

# %%
processor = DataProcessing()
final_df = processor.merge_final_df(tweets, mp_df)
# Out:
# <ipython-input-142-57e6f80a9d4b>:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   mp_df["m.name"] = mp_df["m.name"].str.replace(remove, "")

# %%
#remove = r"(^Hon\s{1}|^Mr\s{1}|^Ms\s{1}|^Dr\s{1}|^Mrs\{s}|\s{1}MP)"
#final_df["m.name"] = final_df["m.name"].str.replace(remove, "")
final_df["m.name"].unique()
# Out:
# array(['Alan Tudge', 'Alex Hawke', 'Andrew Laming', 'Andrew Wallace',
#        'Angus Taylor', 'Bert van Manen', 'Russell Broadbent',
#        'Chris Crewther', 'Christian Porter', 'Christopher Pyne',
#        'Craig Kelly', 'Dan Tehan', 'David Coleman', 'Greg Hunt',
#        'Ian Goodenough', 'Jane Prentice', 'Jason Falinski', 'Jason Wood',
#        'Josh Frydenberg', 'Julian Leeser', 'Julie Bishop',
#        'Karen Andrews', "Kelly O'Dwyer", 'Ken Wyatt,', 'Ken Wyatt',
#        'Kevin Andrews', 'Craig Laundy', 'Lucy Wicks', nan,
#        'Michael Sukkar', 'Nicolle Flint', 'Nola Marino', 'Paul Fletcher',
#        'Peter Dutton', 'Rowan Ramsey', 'Scott Buchholz', 'Scott Morrison',
#        'Sarah Henderson', 'Steven Ciobo', 'Stuart Robert', 'Sussan Ley',
#        "Ted O'Brien", 'Tim Wilson', 'Tony Abbott', 'Tony Pasin',
#        'Malcolm Turnbull', 'Tony Smith', 'James Stevens', 'Gladys Liu',
#        'Fiona Martin', 'Dave Sharma', 'Anthony Albanese',
#        'Dr Andrew Leigh', 'Andrew Leigh', 'Amanda Rishworth',
#        'Andrew Giles', 'Anne Stanley', 'Anthony Byrne', 'Bill Shorten',
#        "Brendan O'Connor", 'Chris Bowen', 'Brian Mitchell',
#        'Catherine King', "Clare O'Neil", 'Emma Husar', 'Joel Fitzgibbon',
#        'Gai Brodtmann', 'Graham Perrett', 'Jason Clare',
#        'Dr Jim Chalmers', 'Jim Chalmers', 'Justine Elliot', 'Joanne Ryan',
#        'Josh Wilson', 'Julie Collins', 'Julie Owens', 'Justine Keay',
#        'Kate Ellis', 'Linda Burney', 'Lisa Chesters', 'Luke Gosling,',
#        'Luke Gosling', 'Madeleine King', 'Warren Snowdon',
#        'Maria Vamvakinou', 'Mark Butler', 'Mark Dreyfus,', 'Mark Dreyfus',
#        'Matt Keogh', 'Meryl Swanson', 'Michael Danby', 'Dr Mike Kelly,',
#        'Mike Kelly', 'Milton Dick', 'Michelle Rowland',
#        'Matt Thistlethwaite', 'Nick Champion', 'Pat Conroy',
#        'Peter Khalil', 'Richard Marles', 'Rob Mitchell', 'Ross Hart',
#        'Sharon Bird', 'Sharon Claydon', 'Shayne Neumann',
#        'Susan Templeman', 'Stephen Jones', 'Steve Georganas',
#        'Susan Lamb', 'Wayne Swan', 'Tanya Plibersek', 'Terri Butler',
#        'Tim Hammond', 'Tim Watts', 'Tony Burke', 'Peta Murphy',
#        'Patrick Gorman', 'Libby Coker', 'Kate Thwaites', 'Josh Burns',
#        'Ged Kearney', 'Fiona Phillips', 'Emma McBride', 'David Smith',
#        'Daniel Mulino', 'Anika Wells', 'Alicia Payne', 'Barnaby Joyce',
#        'David Littleproud', 'Damian Drum', 'Darren Chester',
#        'Dr David Gillespie', 'David Gillespie', 'Keith Pitt',
#        "Ken O'Dowd", 'Kevin Hogan', 'Michael McCormack', 'Mark Coulton',
#        'Pat Conaghan', 'Anne Webster', 'Rebekha Sharkie', 'Adam Bandt',
#        'Cathy McGowan,', 'Andrew Wilkie', 'Bob Katter',
#        'Phillip Thompson'], dtype=object)

# %%
len(final_df["m.name"].unique())
# Out:
# 145

# %%
tweets = tweets.dropna(subset=["screen_name"])

# %% [markdown]
# ### MP info

# %%
#Filter by Australian Parlamentarians
#Download the file full_member_info at http://twitterpoliticians.org/download
mp_df = mp_df[['p.country', 'm.name', 'p.party', 'm.uid', 'lp.official_legislative_period']].copy()
mp_df = mp_df.loc[mp_df["p.country"]=="Australia"]
mp_df["m.name"] = mp_df["m.name"].str.replace(r"^Hon\s{1}|^Mr\s{1}|\s{1}MP|\s{1}Ms", "")
mp_info =  mp_df.loc[mp_df["m.uid"] != "\\N"]
mp_info["m.uid"] = mp_info["m.uid"].astype(int)
# Out:
# <ipython-input-290-203387997bde>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   mp_df["m.name"] = mp_df["m.name"].str.replace(r"^Hon\s{1}|^Mr\s{1}|\s{1}MP", "")
# <ipython-input-290-203387997bde>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mp_info["m.uid"] = mp_info["m.uid"].astype(int)

# %%
tweets["m.uid"] = tweets["m.uid"].astype(int)

# %%
tweets = tweets.merge(mp_info, on = "m.uid", how = "left")

# %%
tweets
# Out:
#          screen_name               m.uid      tweet_id          created_at  \
# 0        AlanTudgeMP           185932331  1.389486e+18 2021-05-04 07:42:40
# 1        AlanTudgeMP           185932331  1.389486e+18 2021-05-04 07:42:40
# 2        AlanTudgeMP           185932331  1.389434e+18 2021-05-04 04:18:43
# 3        AlanTudgeMP           185932331  1.389434e+18 2021-05-04 04:18:43
# 4        AlanTudgeMP           185932331  1.389430e+18 2021-05-04 04:01:51
# ...              ...                 ...           ...                 ...
# 575232  P_Thompson88  929896339307053056  9.302562e+17 2017-11-14 02:08:55
# 575233  P_Thompson88  929896339307053056  9.302450e+17 2017-11-14 01:24:36
# 575234  P_Thompson88  929896339307053056  9.298999e+17 2017-11-13 02:33:07
# 575235  P_Thompson88  929896339307053056  9.298993e+17 2017-11-13 02:30:38
# 575236  P_Thompson88  929896339307053056  9.298986e+17 2017-11-13 02:27:56
#
#                                                 full_text favorite_count  \
# 0       Research commercialisation in action. @QUT wor...             25
# 1       Research commercialisation in action. @QUT wor...             25
# 2       Hearing first hand how our extra $1.7b boost t...              7
# 3       Hearing first hand how our extra $1.7b boost t...              7
# 4       RT @CISOZ: [NEW EDUCATION EVENT]\nTuesday 18 M...              0
# ...                                                   ...            ...
# 575232  A #LivedExperiencedVeteran voice at the macro ...              0
# 575233             #NewProfilePic https://t.co/jVWltJHHRD              1
# 575234  Very honoured to be named the 2018 QLD Young A...             13
# 575235  RT @ausoftheyear: A young veteran’s champion d...              0
# 575236          Just setting up my Twitter. #myfirstTweet              1
#
#         retweet_count in_reply_to_screen_name  \
# 0                 5.0                     NaN
# 1                 5.0                     NaN
# 2                 0.0                     NaN
# 3                 0.0                     NaN
# 4                 5.0                     NaN
# ...               ...                     ...
# 575232            0.0                     NaN
# 575233            0.0                     NaN
# 575234            6.0                     NaN
# 575235            5.0                     NaN
# 575236            0.0                     NaN
#
#                                                  hashtags  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 575232  ['LivedExperiencedVeteran', 'SuicidePrevention...
# 575233                                  ['NewProfilePic']
# 575234  ['SuicidePrevention', 'veteransuicidepreventio...
# 575235                                            ['QLD']
# 575236                                   ['myfirstTweet']
#
#                           user_mentions  url  image_url  p.country  \
# 0             ['QUT', 'TrevorEvansBne']  NaN        NaN  Australia
# 1             ['QUT', 'TrevorEvansBne']  NaN        NaN  Australia
# 2       ['GoodStartel', 'BertVanManen']  NaN        NaN  Australia
# 3       ['GoodStartel', 'BertVanManen']  NaN        NaN  Australia
# 4              ['CISOZ', 'AlanTudgeMP']  NaN        NaN  Australia
# ...                                 ...  ...        ...        ...
# 575232                               []  NaN        NaN  Australia
# 575233                               []  NaN        NaN  Australia
# 575234                               []  NaN        NaN  Australia
# 575235                 ['ausoftheyear']  NaN        NaN  Australia
# 575236                               []  NaN        NaN  Australia
#
#                   m.name                               p.party  \
# 0             Alan Tudge            Liberal Party of Australia
# 1             Alan Tudge            Liberal Party of Australia
# 2             Alan Tudge            Liberal Party of Australia
# 3             Alan Tudge            Liberal Party of Australia
# 4             Alan Tudge            Liberal Party of Australia
# ...                  ...                                   ...
# 575232  Phillip Thompson  Liberal National Party of Queensland
# 575233  Phillip Thompson  Liberal National Party of Queensland
# 575234  Phillip Thompson  Liberal National Party of Queensland
# 575235  Phillip Thompson  Liberal National Party of Queensland
# 575236  Phillip Thompson  Liberal National Party of Queensland
#
#        lp.official_legislative_period
# 0                                  45
# 1                                  46
# 2                                  45
# 3                                  46
# 4                                  45
# ...                               ...
# 575232                             46
# 575233                             46
# 575234                             46
# 575235                             46
# 575236                             46
#
# [575237 rows x 16 columns]

# %%
#tweets["created_at"] = pd.to_datetime(tweets["created_at"], format="%Y-%m-%d")

# %%
len(subset["tweet_id"].unique())
# Out:
# 299139

# %%
subset.to_csv("tweets_subset")

# %% [markdown]
# ## Check how many mps

# %%
mp_df = pd.read_csv("data/full_member_info.csv")
mp_df = mp_df[['p.country', 'm.member_id', 'm.name', 'p.party', 'm.uid', 'lp.official_legislative_period']].copy()
mp_df = mp_df.loc[mp_df["p.country"]=="Australia"]

# %%
tweet_users = pd.read_csv("data/australian_mps.csv", index_col= 0)

# %%
tweet_users.loc[tweet_users["twitter_handle"].isna()]
# Out:
#        p.country                    m.name  \
# 13657  Australia       Mrs Ann Sudmalis MP
# 13671  Australia        Dr John McVeigh MP
# 13673  Australia         Ms Julia Banks MP
# 13682  Australia        Mr Luke Howarth MP
# 13684  Australia     Hon Michael Keenan MP
# 13695  Australia         Mr Steve Irons MP
# 13765  Australia       Ms Cathy O'Toole MP
# 13769  Australia        Ms Emma McBride MP
# 13827  Australia             Stephen Jones
# 13887  Australia          Mr Andrew Gee MP
# 13889  Australia        Mr Andrew Broad MP
# 13894  Australia  Mr George Christensen MP
# 13898  Australia        Mr Llew O'Brien MP
# 13899  Australia    Hon Luke Hartsuyker MP
# 15530  Australia              Luke Howarth
# 15531  Australia              Llew O'Brien
# 15536  Australia              John McVeigh
#
#                                     p.party               m.uid twitter_handle
# 13657            Liberal Party of Australia  835797426229256192            NaN
# 13671            Liberal Party of Australia           929086908            NaN
# 13673            Liberal Party of Australia  753170760252784641            NaN
# 13682            Liberal Party of Australia          4882704458            NaN
# 13684            Liberal Party of Australia          3476724493            NaN
# 13695            Liberal Party of Australia            22147650            NaN
# 13765                Australian Labor Party           808712768            NaN
# 13769                Australian Labor Party  702698265695760000            NaN
# 13827                Australian Labor Party           117273312            NaN
# 13887                         The Nationals           423966765            NaN
# 13889                         The Nationals          1401187418            NaN
# 13894                         The Nationals            17338684            NaN
# 13898                         The Nationals  749898673648119808            NaN
# 13899                         The Nationals          2225832145            NaN
# 15530  Liberal National Party of Queensland          4882704458            NaN
# 15531  Liberal National Party of Queensland  749898673648119808            NaN
# 15536  Liberal National Party of Queensland           929086908            NaN

# %%
len(mp_df["m.member_id"].unique())
# Out:
# 297

# %%
#Unique twitter uid in the original mp_info data
len(tweet_users["m.uid"].unique())
# Out:
# 158

# %%
#Unique twitter handles we were able to fetch based on uid
len(tweet_users["twitter_handle"].unique())
# Out:
# 145

# %%
tweet_users["m.uid"] = tweet_users["m.uid"].astype(str)

# %%
merged = mp_df.merge(tweet_users, on = "m.uid", how = "left")

# %%
#merged = merged.drop_duplicates(subset="m.uid")

# %%
merged
# Out:
#     p.country_x  m.member_id                 m.name_x  \
# 0     Australia         9511       Mr Trevor Evans MP
# 5     Australia         9522        Hon Alan Tudge MP
# 7     Australia         9525        Hon Alex Hawke MP
# 9     Australia         9529      Mr Andrew Laming MP
# 11    Australia         9530     Mr Andrew Wallace MP
# ..          ...          ...                      ...
# 452   Australia         9565  Ms Cathy McGowan AO, MP
# 453   Australia         9659      Mr Andrew Wilkie MP
# 454   Australia         9627        Hon Bob Katter MP
# 461   Australia        14328             Trevor Evans
# 469   Australia        14358         Phillip Thompson
#
#                                 p.party_x                m.uid  \
# 0              Liberal Party of Australia                   \N
# 5              Liberal Party of Australia            185932331
# 7              Liberal Party of Australia             18864066
# 9              Liberal Party of Australia             49499855
# 11             Liberal Party of Australia            252016955
# ..                                    ...                  ...
# 452                           Independent            364814582
# 453                           Independent            398422158
# 454             Katter's Australian Party            310726037
# 461  Liberal National Party of Queensland  1046961420493971456
# 469  Liberal National Party of Queensland   929896339307053056
#
#     lp.official_legislative_period p.country_y                 m.name_y  \
# 0                               45         NaN                      NaN
# 5                               45   Australia        Hon Alan Tudge MP
# 7                               45   Australia        Hon Alex Hawke MP
# 9                               45   Australia      Mr Andrew Laming MP
# 11                              45   Australia     Mr Andrew Wallace MP
# ..                             ...         ...                      ...
# 452                             45   Australia  Ms Cathy McGowan AO, MP
# 453                             45   Australia      Mr Andrew Wilkie MP
# 454                             45   Australia        Hon Bob Katter MP
# 461                             46   Australia             Trevor Evans
# 469                             46   Australia         Phillip Thompson
#
#                                 p.party_y   twitter_handle
# 0                                     NaN              NaN
# 5              Liberal Party of Australia      AlanTudgeMP
# 7              Liberal Party of Australia      AlexHawkeMP
# 9              Liberal Party of Australia   AndrewLamingMP
# 11             Liberal Party of Australia  AndrewWallaceMP
# ..                                    ...              ...
# 452                           Independent      Indigocathy
# 453                           Independent         WilkieMP
# 454             Katter's Australian Party    RealBobKatter
# 461  Liberal National Party of Queensland   TrevorEvansBne
# 469  Liberal National Party of Queensland     P_Thompson88
#
# [159 rows x 10 columns]
